# %% [markdown]
# # Prepare Stratification BEDS fro GitHub and validation

# %% [markdown]
# This notebook describes the process for preparing the new (2019) GRCh37 and GRCh38 stratification BEDs for depositing on GitHub.  These files have been transferred from the following directories on the NAS for processing and validation within the GRCh38_stratificaiton validation R project directory.
#
# #### GRCh37 Stratifications
# /Volumes/giab/analysis/benchmarking-tools/resources/stratification-bed-files
#
# #### GRCh38 Stratifications
# /Volumes/giab/analysis/GRCh38_stratification_bed_files
#
# #### Ns files
# refN and PSA Y files for subtraction generated with refN_analysis_and_creation.sh

# %% [markdown]
# ## Prepare first batch of files

# %%
date
WKDIR=/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/
INPUT38=${WKDIR}GRCh38/
INPUT37=${WKDIR}GRCh37/
OUTPUT38=${WKDIR}GRCh38/sorted_merged_noNs/
OUTPUT37=${WKDIR}GRCh37/sorted_merged_noNs/
refNs=${WKDIR}refNs/
# Out:
# Mon Jan  6 15:53:06 EST 2020

# %% [markdown]
# #### Create header file for BEDs

# %%
echo "#This is part of a collection of bed files intended to stratify performance by genome context using GA4GH benchmarking tools" > ${WKDIR}header.txt

# %% [markdown]
# ### Sort -> cut to chrom 1:22 XY -> merge -> subtract refNs (gap) -> subtract Pseudoautosomal Y regions

# %% [markdown]
# #### GRCh38

# %%
date
bedtools --version 

for f in ${INPUT38}*.gz
do
    OUTFILE=${OUTPUT38}/$( basename ${f})
    
	gzcat $f |
    sed 's/^chr//'|
    sed 's/^X/23/;s/^Y/24/'|
    grep -Ev '^M|^[0-9][0-9]_|^[0-9]_|^[0-9]\||^[0-9][0-9]\||^Un|^HS'|
    sort -k1,1n -k2,2n -k3,3n  |
    mergeBed -i stdin |
	sed 's/^23/X/;s/^24/Y/' |
    sed 's/^[a-zA-Z0-9_]/chr&/'|
    subtractBed -a stdin -b ${refNs}gap_38_1thruY_sorted_merged.bed | 
	subtractBed -a stdin -b ${refNs}PSA_Y_GRCh38.bed | 
    cat ${WKDIR}header.txt - | 
 	bgzip > ${OUTFILE}
    echo "processed:  " $( basename ${f})
    md5 ${OUTFILE} >> GRCh38_stratificationBEDs_for_Github_md5s.txt
    
done
# Out:
# Mon Jan  6 16:44:24 EST 2020
# bedtools v2.29.1
# processed:   GRCh38_AllHomopolymers_gt6bp_imperfectgt10bp_slop5.bed.gz
# processed:   GRCh38_AllTandemRepeats_201to10000bp_slop5.bed.gz
# processed:   GRCh38_AllTandemRepeats_51to200bp_slop5.bed.gz
# processed:   GRCh38_AllTandemRepeats_gt10000bp_slop5.bed.gz
# processed:   GRCh38_AllTandemRepeats_gt100bp_slop5.bed.gz
# processed:   GRCh38_AllTandemRepeats_lt51bp_slop5.bed.gz
# processed:   GRCh38_AllTandemRepeatsandHomopolymers_slop5.bed.gz
# processed:   GRCh38_SimpleRepeat_diTR_11to50_slop5.bed.gz
# processed:   GRCh38_SimpleRepeat_diTR_51to200_slop5.bed.gz
# processed:   GRCh38_SimpleRepeat_diTR_gt200_slop5.bed.gz
# processed:   GRCh38_SimpleRepeat_homopolymer_4to6_slop5.bed.gz
# processed:   GRCh38_SimpleRepeat_homopolymer_7to11_slop5.bed.gz
# processed:   GRCh38_SimpleRepeat_homopolymer_gt11_slop5.bed.gz
# processed:   GRCh38_SimpleRepeat_imperfecthomopolgt10_slop5.bed.gz
# processed:   GRCh38_SimpleRepeat_quadTR_20to50_slop5.bed.gz
# processed:   GRCh38_SimpleRepeat_quadTR_51to200_slop5.bed.gz
# processed:   GRCh38_SimpleRepeat_quadTR_gt200_slop5.bed.gz
# processed:   GRCh38_SimpleRepeat_triTR_15to50_slop5.bed.gz
# processed:   GRCh38_SimpleRepeat_triTR_51to200_slop5.bed.gz
# processed:   GRCh38_SimpleRepeat_triTR_gt200_slop5.bed.gz
# processed:   GRCh38_alldifficultregions.bed.gz
# processed:   GRCh38_chainSelf_sorted_merged.bed.gz
# processed:   GRCh38_chainSelf_sorted_merged_gt10kb.bed.gz
# processed:   GRCh38_l100_gc15_slop50.bed.gz
# processed:   GRCh38_l100_gc15to20_slop50.bed.gz
# processed:   GRCh38_l100_gc20to25_slop50.bed.gz
# processed:   GRCh38_l100_gc25to30_slop50.bed.gz
# processed:   GRCh38_l100_gc30to55_slop50.bed.gz
# processed:   GRCh38_l100_gc55to60_slop50.bed.gz
# processed:   GRCh38_l100_gc60to65_slop50.bed.gz
# processed:   GRCh38_l100_gc65to70_slop50.bed.gz
# processed:   GRCh38_l100_gc70to75_slop50.bed.gz
# processed:   GRCh38_l100_gc75to80_slop50.bed.gz
# processed:   GRCh38_l100_gc80to85_slop50.bed.gz
# processed:   GRCh38_l100_gc85_slop50.bed.gz
# processed:   GRCh38_l100_gclt25orgt65_slop50.bed.gz
# processed:   GRCh38_l100_gclt30orgt55_slop50.bed.gz
# processed:   GRCh38_lowmappabilityall.bed.gz
# processed:   GRCh38_no_alt_gemmap_l100_m2_e1_nonuniq.sort.bed.gz
# processed:   GRCh38_no_alt_gemmap_l250_m0_e0_nonuniq.sort.bed.gz
# processed:   GRCh38_notinAllHomopolymers_gt6bp_imperfectgt10bp_slop5.bed.gz
# processed:   GRCh38_notinAllTandemRepeatsandHomopolymers_slop5.bed.gz
# processed:   GRCh38_notinalldifficultregions.bed.gz
# processed:   GRCh38_notinchainSelf_sorted_merged.bed.gz
# processed:   GRCh38_notinchainSelf_sorted_merged_gt10kb.bed.gz
# processed:   GRCh38_notinlowmappabilityall.bed.gz
# processed:   GRCh38_refseq_cds_merged.bed.gz
# processed:   GRCh38_remapped_BadPromoters_gb-2013-14-5-r51-s1.bed.gz
# processed:   GRCh38_remapped_HG001_GRCh37_GIAB_highconf_CG-IllFB-IllGATKHC-Ion-10X-SOLID_CHROM1-X_v.3.3.2_highconf_RTGandPGphasetransfer_comphetindel10bp_slop50.bed.gz
# processed:   GRCh38_remapped_HG001_GRCh37_GIAB_highconf_CG-IllFB-IllGATKHC-Ion-10X-SOLID_CHROM1-X_v.3.3.2_highconf_RTGandPGphasetransfer_comphetsnp10bp_slop50.bed.gz
# processed:   GRCh38_remapped_HG001_GRCh37_GIAB_highconf_CG-IllFB-IllGATKHC-Ion-10X-SOLID_CHROM1-X_v.3.3.2_highconf_RTGandPGphasetransfer_complexindel10bp_slop50.bed.gz
# processed:   GRCh38_remapped_HG001_GRCh37_GIAB_highconf_CG-IllFB-IllGATKHC-Ion-10X-SOLID_CHROM1-X_v.3.3.2_highconf_RTGandPGphasetransfer_snpswithin10bp_slop50.bed.gz
# processed:   GRCh38_remapped_HG002_GIAB_highconf_IllFB-IllGATKHC-CG-Ion-Solid_CHROM1-22_v3.2.2_highconf_geno2haplo_compoundhet_slop50.bed.gz
# processed:   GRCh38_remapped_HG002_GIAB_highconf_IllFB-IllGATKHC-CG-Ion-Solid_CHROM1-22_v3.2.2_highconf_varswithin50bp.bed.gz
# processed:   GRCh38_remapped_HG002_GRCh37_GIAB_highconf_CG-IllFB-IllGATKHC-Ion-10X-SOLID_CHROM1-22_v.3.3.2_highconf_triophased_comphetindel10bp_slop50.bed.gz
# processed:   GRCh38_remapped_HG002_GRCh37_GIAB_highconf_CG-IllFB-IllGATKHC-Ion-10X-SOLID_CHROM1-22_v.3.3.2_highconf_triophased_comphetsnp10bp_slop50.bed.gz
# processed:   GRCh38_remapped_HG002_GRCh37_GIAB_highconf_CG-IllFB-IllGATKHC-Ion-10X-SOLID_CHROM1-22_v.3.3.2_highconf_triophased_complexindel10bp_slop50.bed.gz
# processed:   GRCh38_remapped_HG002_GRCh37_GIAB_highconf_CG-IllFB-IllGATKHC-Ion-10X-SOLID_CHROM1-22_v.3.3.2_highconf_triophased_snpswithin10bp_slop50.bed.gz
# processed:   GRCh38_remapped_HG002_HG003_HG004_allsvs_merged.bed.gz
# processed:   GRCh38_remapped_HG002_SVs_Tier1plusTier2_v0.6.1.bed.gz
# processed:   GRCh38_remapped_HG003_GRCh37_GIAB_highconf_CG-IllFB-IllGATKHC-Ion-10X_CHROM1-22_v.3.3.2_highconf_comphetindel10bp_slop50.bed.gz
# processed:   GRCh38_remapped_HG003_GRCh37_GIAB_highconf_CG-IllFB-IllGATKHC-Ion-10X_CHROM1-22_v.3.3.2_highconf_comphetsnp10bp_slop50.bed.gz
# processed:   GRCh38_remapped_HG003_GRCh37_GIAB_highconf_CG-IllFB-IllGATKHC-Ion-10X_CHROM1-22_v.3.3.2_highconf_complexindel10bp_slop50.bed.gz
# processed:   GRCh38_remapped_HG003_GRCh37_GIAB_highconf_CG-IllFB-IllGATKHC-Ion-10X_CHROM1-22_v.3.3.2_highconf_snpswithin10bp_slop50.bed.gz
# processed:   GRCh38_remapped_HG004_GRCh37_GIAB_highconf_CG-IllFB-IllGATKHC-Ion-10X_CHROM1-22_v.3.3.2_highconf_comphetindel10bp_slop50.bed.gz
# processed:   GRCh38_remapped_HG004_GRCh37_GIAB_highconf_CG-IllFB-IllGATKHC-Ion-10X_CHROM1-22_v.3.3.2_highconf_comphetsnp10bp_slop50.bed.gz
# processed:   GRCh38_remapped_HG004_GRCh37_GIAB_highconf_CG-IllFB-IllGATKHC-Ion-10X_CHROM1-22_v.3.3.2_highconf_complexindel10bp_slop50.bed.gz
# processed:   GRCh38_remapped_HG004_GRCh37_GIAB_highconf_CG-IllFB-IllGATKHC-Ion-10X_CHROM1-22_v.3.3.2_highconf_snpswithin10bp_slop50.bed.gz
# processed:   GRCh38_remapped_HG005_GRCh37_highconf_CG-IllFB-IllGATKHC-Ion-SOLID_CHROM1-22_v.3.3.2_highconf_comphetindel10bp_slop50.bed.gz
# processed:   GRCh38_remapped_HG005_GRCh37_highconf_CG-IllFB-IllGATKHC-Ion-SOLID_CHROM1-22_v.3.3.2_highconf_comphetsnp10bp_slop50.bed.gz
# processed:   GRCh38_remapped_HG005_GRCh37_highconf_CG-IllFB-IllGATKHC-Ion-SOLID_CHROM1-22_v.3.3.2_highconf_complexindel10bp_slop50.bed.gz
# processed:   GRCh38_remapped_HG005_GRCh37_highconf_CG-IllFB-IllGATKHC-Ion-SOLID_CHROM1-22_v.3.3.2_highconf_snpswithin10bp_slop50.bed.gz
# processed:   GRCh38_remapped_HG005_HG006_HG007_FB_GATKHC_CG_MetaSV_allsvs_merged.bed.gz
# processed:   GRCh38_remapped_NA12878_GIAB_highconf_IllFB-IllGATKHC-CG-Ion-Solid_ALLCHROM_v3.2.2_highconf_geno2haplo_compoundhet_slop50.bed.gz
# processed:   GRCh38_remapped_NA12878_GIAB_highconf_IllFB-IllGATKHC-CG-Ion-Solid_ALLCHROM_v3.2.2_highconf_varswithin50bp.bed.gz
# processed:   GRCh38_remapped_PG2016-1.0_NA12878_b37_comphetindel10bp_slop50.bed.gz
# processed:   GRCh38_remapped_PG2016-1.0_NA12878_b37_comphetsnp10bp_slop50.bed.gz
# processed:   GRCh38_remapped_PG2016-1.0_NA12878_b37_complexindel10bp_slop50.bed.gz
# processed:   GRCh38_remapped_PG2016-1.0_NA12878_b37_snpswithin10bp_slop50.bed.gz
# processed:   GRCh38_remapped_PacBio_MetaSV_mergedSVs.bed.gz
# processed:   GRCh38_remapped_sp_v37.7.3.NA12878_comphetindel10bp_slop50.bed.gz
# processed:   GRCh38_remapped_sp_v37.7.3.NA12878_comphetsnp10bp_slop50.bed.gz
# processed:   GRCh38_remapped_sp_v37.7.3.NA12878_complexindel10bp_slop50.bed.gz
# processed:   GRCh38_remapped_sp_v37.7.3.NA12878_snpswithin10bp_slop50.bed.gz
# processed:   hg38.notinsegdups_sorted_merged.bed.gz
# processed:   hg38.notinsegdups_sorted_merged_gt10kb.bed.gz
# processed:   hg38.segdups_sorted_merged.bed.gz
# processed:   hg38.segdups_sorted_merged_gt10kb.bed.gz
# processed:   notin_GRCh38_refseq_cds_merged.bed.gz

# %% [markdown]
# #### GRCh37

# %%
date
bedtools --version 

for f in ${INPUT37}*.gz
do
    OUTFILE=${OUTPUT37}/$( basename ${f})
    
	gzcat $f |
    sed 's/^chr//'|
    sed 's/^X/23/;s/^Y/24/'|
    grep -Ev '^M|^[0-9][0-9]_|^[0-9]_|^[0-9]\||^[0-9][0-9]\||^Un|^HS'|
    sort -k1,1n -k2,2n -k3,3n  |
    mergeBed -i stdin |
	sed 's/^23/X/;s/^24/Y/' |
    subtractBed -a stdin -b ${refNs}hg19.gap_1thruY_sorted_merged.bed | 
	subtractBed -a stdin -b ${refNs}PSA_Y_hg19.bed | 
    cat header.txt - | 
 	bgzip > ${OUTFILE}
     echo "processed:  " $( basename ${f})
    md5 ${OUTFILE} >> GRCh37_stratificationBEDs_for_Github_md5s.txt
    
done
# Out:
# Mon Jan  6 17:03:28 EST 2020
# bedtools v2.29.1
# processed:   AllHomopolymers_gt6bp_imperfectgt10bp_slop5.bed.gz
# processed:   AllTandemRepeats_201to10000bp_slop5.bed.gz
# processed:   AllTandemRepeats_51to200bp_slop5.bed.gz
# processed:   AllTandemRepeats_gt10000bp_slop5.bed.gz
# processed:   AllTandemRepeats_gt100bp_slop5.bed.gz
# processed:   AllTandemRepeats_lt51bp_slop5.bed.gz
# processed:   AllTandemRepeatsandHomopolymers_slop5.bed.gz
# processed:   BadPromoters_gb-2013-14-5-r51-s1.bed.gz
# processed:   GRCh37_chainSelf_sorted_merged.bed.gz
# processed:   GRCh37_chainSelf_sorted_merged_gt10kb.bed.gz
# processed:   GRCh37_notinchainSelf_sorted_merged.bed.gz
# processed:   GRCh37_notinchainSelf_sorted_merged_gt10kb.bed.gz
# processed:   HG001_GRCh37_GIAB_highconf_CG-IllFB-IllGATKHC-Ion-10X-SOLID_CHROM1-X_v.3.3.2_highconf_RTGandPGphasetransfer_comphetindel10bp_slop50.bed.gz
# processed:   HG001_GRCh37_GIAB_highconf_CG-IllFB-IllGATKHC-Ion-10X-SOLID_CHROM1-X_v.3.3.2_highconf_RTGandPGphasetransfer_comphetsnp10bp_slop50.bed.gz
# processed:   HG001_GRCh37_GIAB_highconf_CG-IllFB-IllGATKHC-Ion-10X-SOLID_CHROM1-X_v.3.3.2_highconf_RTGandPGphasetransfer_complexindel10bp_slop50.bed.gz
# processed:   HG001_GRCh37_GIAB_highconf_CG-IllFB-IllGATKHC-Ion-10X-SOLID_CHROM1-X_v.3.3.2_highconf_RTGandPGphasetransfer_snpswithin10bp_slop50.bed.gz
# processed:   HG002_GIAB_highconf_IllFB-IllGATKHC-CG-Ion-Solid_CHROM1-22_v3.2.2_highconf_geno2haplo_compoundhet_slop50.bed.gz
# processed:   HG002_GIAB_highconf_IllFB-IllGATKHC-CG-Ion-Solid_CHROM1-22_v3.2.2_highconf_varswithin50bp.bed.gz
# processed:   HG002_GRCh37_GIAB_highconf_CG-IllFB-IllGATKHC-Ion-10X-SOLID_CHROM1-22_v.3.3.2_highconf_triophased_comphetindel10bp_slop50.bed.gz
# processed:   HG002_GRCh37_GIAB_highconf_CG-IllFB-IllGATKHC-Ion-10X-SOLID_CHROM1-22_v.3.3.2_highconf_triophased_comphetsnp10bp_slop50.bed.gz
# processed:   HG002_GRCh37_GIAB_highconf_CG-IllFB-IllGATKHC-Ion-10X-SOLID_CHROM1-22_v.3.3.2_highconf_triophased_complexindel10bp_slop50.bed.gz
# processed:   HG002_GRCh37_GIAB_highconf_CG-IllFB-IllGATKHC-Ion-10X-SOLID_CHROM1-22_v.3.3.2_highconf_triophased_snpswithin10bp_slop50.bed.gz
# processed:   HG002_HG003_HG004_allsvs_merged.bed.gz
# processed:   HG002_SVs_Tier1plusTier2_v0.6.1.bed.gz
# processed:   HG003_GRCh37_GIAB_highconf_CG-IllFB-IllGATKHC-Ion-10X_CHROM1-22_v.3.3.2_highconf_comphetindel10bp_slop50.bed.gz
# processed:   HG003_GRCh37_GIAB_highconf_CG-IllFB-IllGATKHC-Ion-10X_CHROM1-22_v.3.3.2_highconf_comphetsnp10bp_slop50.bed.gz
# processed:   HG003_GRCh37_GIAB_highconf_CG-IllFB-IllGATKHC-Ion-10X_CHROM1-22_v.3.3.2_highconf_complexindel10bp_slop50.bed.gz
# processed:   HG003_GRCh37_GIAB_highconf_CG-IllFB-IllGATKHC-Ion-10X_CHROM1-22_v.3.3.2_highconf_snpswithin10bp_slop50.bed.gz
# processed:   HG004_GRCh37_GIAB_highconf_CG-IllFB-IllGATKHC-Ion-10X_CHROM1-22_v.3.3.2_highconf_comphetindel10bp_slop50.bed.gz
# processed:   HG004_GRCh37_GIAB_highconf_CG-IllFB-IllGATKHC-Ion-10X_CHROM1-22_v.3.3.2_highconf_comphetsnp10bp_slop50.bed.gz
# processed:   HG004_GRCh37_GIAB_highconf_CG-IllFB-IllGATKHC-Ion-10X_CHROM1-22_v.3.3.2_highconf_complexindel10bp_slop50.bed.gz
# processed:   HG004_GRCh37_GIAB_highconf_CG-IllFB-IllGATKHC-Ion-10X_CHROM1-22_v.3.3.2_highconf_snpswithin10bp_slop50.bed.gz
# processed:   HG005_GRCh37_highconf_CG-IllFB-IllGATKHC-Ion-SOLID_CHROM1-22_v.3.3.2_highconf_comphetindel10bp_slop50.bed.gz
# processed:   HG005_GRCh37_highconf_CG-IllFB-IllGATKHC-Ion-SOLID_CHROM1-22_v.3.3.2_highconf_comphetsnp10bp_slop50.bed.gz
# processed:   HG005_GRCh37_highconf_CG-IllFB-IllGATKHC-Ion-SOLID_CHROM1-22_v.3.3.2_highconf_complexindel10bp_slop50.bed.gz
# processed:   HG005_GRCh37_highconf_CG-IllFB-IllGATKHC-Ion-SOLID_CHROM1-22_v.3.3.2_highconf_snpswithin10bp_slop50.bed.gz
# processed:   HG005_HG006_HG007_FB_GATKHC_CG_MetaSV_allsvs_merged.bed.gz
# processed:   NA12878_GIAB_highconf_IllFB-IllGATKHC-CG-Ion-Solid_ALLCHROM_v3.2.2_highconf_geno2haplo_compoundhet_slop50.bed.gz
# processed:   NA12878_GIAB_highconf_IllFB-IllGATKHC-CG-Ion-Solid_ALLCHROM_v3.2.2_highconf_varswithin50bp.bed.gz
# processed:   PG2016-1.0_NA12878_b37_comphetindel10bp_slop50.bed.gz
# processed:   PG2016-1.0_NA12878_b37_comphetsnp10bp_slop50.bed.gz
# processed:   PG2016-1.0_NA12878_b37_complexindel10bp_slop50.bed.gz
# processed:   PG2016-1.0_NA12878_b37_snpswithin10bp_slop50.bed.gz
# processed:   PacBio_MetaSV_mergedSVs.bed.gz
# processed:   SimpleRepeat_diTR_11to50_slop5.bed.gz
# processed:   SimpleRepeat_diTR_51to200_slop5.bed.gz
# processed:   SimpleRepeat_diTR_gt200_slop5.bed.gz
# processed:   SimpleRepeat_homopolymer_4to6_slop5.bed.gz
# processed:   SimpleRepeat_homopolymer_7to11_slop5.bed.gz
# processed:   SimpleRepeat_homopolymer_gt11_slop5.bed.gz
# processed:   SimpleRepeat_imperfecthomopolgt10_slop5.bed.gz
# processed:   SimpleRepeat_quadTR_20to50_slop5.bed.gz
# processed:   SimpleRepeat_quadTR_51to200_slop5.bed.gz
# processed:   SimpleRepeat_quadTR_gt200_slop5.bed.gz
# processed:   SimpleRepeat_triTR_15to50_slop5.bed.gz
# processed:   SimpleRepeat_triTR_51to200_slop5.bed.gz
# processed:   SimpleRepeat_triTR_gt200_slop5.bed.gz
# processed:   hg19.notinsegdups_sorted_merged.bed.gz
# processed:   hg19.notinsegdups_sorted_merged_gt10kb.bed.gz
# processed:   hg19.segdups_sorted_merged.bed.gz
# processed:   hg19.segdups_sorted_merged_gt10kb.bed.gz
# processed:   human_g1k_v37_gemmap_l100_m0_e0_nonuniq.sort.bed.gz
# processed:   human_g1k_v37_gemmap_l100_m1_e0_nonuniq.sort.bed.gz
# processed:   human_g1k_v37_gemmap_l100_m2_e0_nonuniq.sort.bed.gz
# processed:   human_g1k_v37_gemmap_l100_m2_e1_nonuniq.sort.bed.gz
# processed:   human_g1k_v37_gemmap_l125_m0_e0_nonuniq.sort.bed.gz
# processed:   human_g1k_v37_gemmap_l125_m1_e0_nonuniq.sort.bed.gz
# processed:   human_g1k_v37_gemmap_l125_m2_e0_nonuniq.sort.bed.gz
# processed:   human_g1k_v37_gemmap_l125_m2_e1_nonuniq.sort.bed.gz
# processed:   human_g1k_v37_gemmap_l150_m0_e0_nonuniq.sort.bed.gz
# processed:   human_g1k_v37_gemmap_l150_m1_e0_nonuniq.sort.bed.gz
# processed:   human_g1k_v37_gemmap_l150_m2_e0_nonuniq.sort.bed.gz
# processed:   human_g1k_v37_gemmap_l150_m2_e1_nonuniq.sort.bed.gz
# processed:   human_g1k_v37_gemmap_l250_m0_e0_nonuniq.sort.bed.gz
# processed:   human_g1k_v37_gemmap_l250_m1_e0_nonuniq.sort.bed.gz
# processed:   human_g1k_v37_gemmap_l250_m2_e0_nonuniq.sort.bed.gz
# processed:   human_g1k_v37_gemmap_l250_m2_e1_nonuniq.sort.bed.gz
# processed:   human_g1k_v37_l100_gc15_slop50.bed.gz
# processed:   human_g1k_v37_l100_gc15to20_slop50.bed.gz
# processed:   human_g1k_v37_l100_gc20to25_slop50.bed.gz
# processed:   human_g1k_v37_l100_gc25to30_slop50.bed.gz
# processed:   human_g1k_v37_l100_gc30to55_slop50.bed.gz
# processed:   human_g1k_v37_l100_gc55to60_slop50.bed.gz
# processed:   human_g1k_v37_l100_gc60to65_slop50.bed.gz
# processed:   human_g1k_v37_l100_gc65to70_slop50.bed.gz
# processed:   human_g1k_v37_l100_gc70to75_slop50.bed.gz
# processed:   human_g1k_v37_l100_gc75to80_slop50.bed.gz
# processed:   human_g1k_v37_l100_gc80to85_slop50.bed.gz
# processed:   human_g1k_v37_l100_gc85_slop50.bed.gz
# processed:   human_g1k_v37_l100_gclt25orgt65_slop50.bed.gz
# processed:   human_g1k_v37_l100_gclt30orgt55_slop50.bed.gz
# processed:   lowmappabilityall.bed.gz
# processed:   lowmappabilityall_GRCh38equivalent.bed.gz
# processed:   notinAllHomopolymers_gt6bp_imperfectgt10bp_slop5.bed.gz
# processed:   notinAllTandemRepeatsandHomopolymers_slop5.bed.gz
# processed:   notinlowmappabilityall.bed.gz
# processed:   notinrefseq_union_cds.sort.bed.gz
# processed:   refseq_union_cds.bed.gz
# processed:   siren_similarRegions_dist1.bed.gz
# processed:   sp_v37.7.3.NA12878_comphetindel10bp_slop50.bed.gz
# processed:   sp_v37.7.3.NA12878_comphetsnp10bp_slop50.bed.gz
# processed:   sp_v37.7.3.NA12878_complexindel10bp_slop50.bed.gz
# processed:   sp_v37.7.3.NA12878_snpswithin10bp_slop50.bed.gz

# %% [markdown]
# #### Notes from running script for both genomes:
#
# 1)Had issues with merging Genome Specific SVs after subtractbed, mergebed seeing the files as unsorted. Decided to reorder process such that merge was completed prior to subtractbed.  Turns out this might not be necessary.  Reran again and had issues. Issues are inconsitent. Things I have tried are running in different browser, running as shell script, clearing output & restarting Kernal and running on a different machine.  I have encountered the "sort" error inconsistently, not always the same file.  The Malloc error has been a problem with RCh38_SimpleRepeat_homopolymer_4to6_slop5.bed.gz however I have gotten it to complete sucessfully.   Errors encountered are below:
#
# Sort Error: "Error: Sorted input specified, but the file stdin has the following out of order record"
#
# Memory Error: "sort(20634,0x1131065c0) malloc: *** error for object 0x7ff200000001: pointer being freed was not allocated
# sort(20634,0x1131065c0) malloc: *** set a breakpoint in malloc_error_break to debug"
#
# 2) In our troubleshooting NDO and I tried to replace the UNIX sort with bedtools sortBed.  While this appeared to work output file was not sorted by chromosome following mergeBed.  I have decided to just continue with UNIX sort which does result in what appears to be a merged-sorted file.
#
# 3) For BEDs Justin wants to make sure we sort with all three fields, sort -k1,1n -k2,2n -k3,3n

# %% [markdown]
# #### Notes on BEDs:
#
# 1) After talkign with NDO decided to only work with refseq_union_cds.bed.gz (for GRCh37). The other files that had been sorted and trimmed down to 3 fields appeared to have issues.  The script in this notebook should accomplish what was being done with the other files.
#
# 2) Previously I have not included HG002_SVs_Tier1plusTier2_v0.6.1.bed.gz (for GRCh37) in my validation.  I asked JW to download from DNAnexus for me because it was not on the NAS.  I have now added this file for comparison with remapped in the validation and have put it on the NAS as well.
#
# 3) Filenames in the output directories will be cleaned up to remove any reference to "sort" and/or "merge". All files in the output directories ...sorted_merged_noNs/ have been sorted and merged.  The use of sort and merge was inconsistent in naming so to be consistent we removed.  It will not hurt if someone sorts and merges these files but will benefit those who have not sorted/merged.
#
# 4) To clarify the difference ... only a subset of the GRCh37 mappability beds were generated for GRCh38, Justin created the lowmappabilityall_GRCh38equivalent.bed.gz as the union of the GRCh37 mappability beds with matching GRCh38 beds. Whereas lowmappaiblityall.bed.gz is the union of all GRCh37 low mappability beds.  Only lowmappabilityall_GRCh38equivalent.bed.gz will be in this release.  lowmappaiblityall.bed.gz will be removed from the directory.

# %% [markdown]
# ## Prepare second batch of files
#
# Justin decided to include some all and notin all and Genomic Specific files that were not originally included.  I'm runnign as a separate code chunk due to issues I had previously with sort and memory errors.  The same script will be used but point to different directories that house the additional files.

# %%
date
WKDIR=/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/
INPUT38batch2=${WKDIR}GRCh38/newfiles_from_JZ_for_processing/
INPUT37batch2=${WKDIR}GRCh37/newfiles_from_JZ_for_processing/
OUTPUT38=${WKDIR}GRCh38/sorted_merged_noNs/
OUTPUT37=${WKDIR}GRCh37/sorted_merged_noNs/
refNs=${WKDIR}refNs/
# Out:
# Wed Jan 22 16:12:02 EST 2020

# %% [markdown]
# <font bold color='red'>NOTE: second batch output files (OUTPUTXX) in GRChXX/sorted_merged_noNs/ were moved to GRChXX/sorted_merged_noNs/second_batch_from_JZ. This was done to aid in the validation of these files with Second_Batch_ChromANDCoveragePlots.R script.  In hindsight I should have just made a directory of symbolic links rather than moving the files.</font>

# %% [markdown]
# #### GRCh37

# %%
##Some input files were zipped and others were not.  This is to check if file is zipped and if not then zip.

date
for f in ${INPUT37batch2}/original_files/*
do
OUTFILE=${INPUT37batch2}/$( basename ${f})

if [[ $f == *.bed ]] 
then
    echo "bgzipped: "$( basename ${f})
    bgzip < $f > ${OUTFILE}.gz
else
     cp $f ${INPUT37batch2}/$( basename ${f})
     echo "already zipped: "$( basename ${f})
fi
done
# Out:
# Wed Jan 22 16:12:15 EST 2020
# already zipped: HG001_genomespecific_RTG_PG_v3.3.2_SVs_alldifficultregions.bed.gz
# bgzipped: HG002_GRCh37_1_22_v4.1_draft_benchmark_comphetindel10bp_slop50.bed
# bgzipped: HG002_GRCh37_1_22_v4.1_draft_benchmark_comphetsnp10bp_slop50.bed
# bgzipped: HG002_GRCh37_1_22_v4.1_draft_benchmark_complexindel10bp_slop50.bed
# bgzipped: HG002_GRCh37_1_22_v4.1_draft_benchmark_othercomplexwithin10bp_slop50.bed
# bgzipped: HG002_GRCh37_1_22_v4.1_draft_benchmark_snpswithin10bp_slop50.bed
# already zipped: HG002_genomespecific_CNVsandSVs_v4.1.bed.gz
# already zipped: HG002_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz
# already zipped: HG002_genomespecific_complexandSVs_alldifficultregions_v4.1.bed.gz
# already zipped: HG002_genomespecific_complexandSVs_v4.1.bed.gz
# bgzipped: HG2_SKor_TrioONTCanu_intersect_HG2_SKor_TrioONTFlye_intersect_HG2_SKor_CCS15_gt10kb_GRCh37.bed
# bgzipped: L1Hs_gt500.bed
# bgzipped: MHC_GRCh37.bed
# bgzipped: SP_SPonly_primary_assm_alignments_sorted_merged.bed
# already zipped: allOtherDifficultregions.bed.gz
# already zipped: alldifficultregions.bed.gz
# already zipped: alllowmapandsegdupregions.bed.gz
# bgzipped: example_of_no_ref_regions_input_file_b37_bedtools_slop_15kb_merged.bed
# bgzipped: expanded_150_HG002_SVs_Tier1plusTier2_v0.6.1.bed
# bgzipped: hg19.contigs.1-22.lt_500kb.bed
# bgzipped: hg19.vdj.bed
# bgzipped: hs37d5_hg38_minimap2_asm20_N10_gt1contig_gt1kb.bed
# bgzipped: hs37d5_hg38_minimap2_asm20_N10_nocovgt1kb.bed
# bgzipped: hsd37d5.112719.inversions_slop150_chr1_22.bed
# bgzipped: mrcanavar_intersect_ccs_1000_window_size_cnv_threshold_intersect_ont_1000_window_size_cnv_threshold.bed
# already zipped: notinHG001_genomespecific_RTG_PG_v3.3.2_SVs_alldifficultregions.bed.gz
# already zipped: notinHG002_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz
# already zipped: notinHG002_genomespecific_complexandSVs_alldifficultregions_v4.1.bed.gz
# already zipped: notinalldifficultregions.bed.gz
# already zipped: notinalllowmapandsegdupregions.bed.gz
# bgzipped: segdups_chr1_22_gte_10kb_identity_gte_990_segdups_counts_gt_5.bed
# bgzipped: union_HG002_CCS_15kb_20kb_merged_ONT_1000_window_size_combined_elliptical_outlier_threshold.bed

# %%
date
bedtools --version 

for f in ${INPUT37batch2}*.gz
do
    OUTFILE=${OUTPUT37}/$( basename ${f})
    
	gzcat $f |
    sed 's/^chr//'|
    sed 's/^X/23/;s/^Y/24/'|
    grep -Ev '^M|^MT|^[0-9][0-9]_|^[0-9]_|^[0-9]\||^[0-9][0-9]\||^Un|^HS'|
    sort -k1,1n -k2,2n -k3,3n  |
    mergeBed -i stdin |
	sed 's/^23/X/;s/^24/Y/' |
    subtractBed -a stdin -b ${refNs}hg19.gap_1thruY_sorted_merged.bed | 
	subtractBed -a stdin -b ${refNs}PSA_Y_hg19.bed | 
    cat header.txt - | 
 	bgzip > ${OUTFILE}
     echo "processed:  " $( basename ${f})
    md5 ${OUTFILE} >> GRCh37_stratificationBEDs_for_Github_md5s.txt
    
done
# Out:
# Wed Jan 22 16:26:38 EST 2020
# bedtools v2.29.1
# processed:   HG001_genomespecific_RTG_PG_v3.3.2_SVs_alldifficultregions.bed.gz
# processed:   HG002_GRCh37_1_22_v4.1_draft_benchmark_comphetindel10bp_slop50.bed.gz
# processed:   HG002_GRCh37_1_22_v4.1_draft_benchmark_comphetsnp10bp_slop50.bed.gz
# processed:   HG002_GRCh37_1_22_v4.1_draft_benchmark_complexindel10bp_slop50.bed.gz
# processed:   HG002_GRCh37_1_22_v4.1_draft_benchmark_othercomplexwithin10bp_slop50.bed.gz
# processed:   HG002_GRCh37_1_22_v4.1_draft_benchmark_snpswithin10bp_slop50.bed.gz
# processed:   HG002_genomespecific_CNVsandSVs_v4.1.bed.gz
# processed:   HG002_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz
# processed:   HG002_genomespecific_complexandSVs_alldifficultregions_v4.1.bed.gz
# processed:   HG002_genomespecific_complexandSVs_v4.1.bed.gz
# processed:   HG2_SKor_TrioONTCanu_intersect_HG2_SKor_TrioONTFlye_intersect_HG2_SKor_CCS15_gt10kb_GRCh37.bed.gz
# processed:   L1Hs_gt500.bed.gz
# processed:   MHC_GRCh37.bed.gz
# processed:   SP_SPonly_primary_assm_alignments_sorted_merged.bed.gz
# processed:   allOtherDifficultregions.bed.gz
# processed:   alldifficultregions.bed.gz
# processed:   alllowmapandsegdupregions.bed.gz
# processed:   example_of_no_ref_regions_input_file_b37_bedtools_slop_15kb_merged.bed.gz
# processed:   expanded_150_HG002_SVs_Tier1plusTier2_v0.6.1.bed.gz
# processed:   hg19.contigs.1-22.lt_500kb.bed.gz
# processed:   hg19.vdj.bed.gz
# processed:   hs37d5_hg38_minimap2_asm20_N10_gt1contig_gt1kb.bed.gz
# processed:   hs37d5_hg38_minimap2_asm20_N10_nocovgt1kb.bed.gz
# processed:   hsd37d5.112719.inversions_slop150_chr1_22.bed.gz
# processed:   mrcanavar_intersect_ccs_1000_window_size_cnv_threshold_intersect_ont_1000_window_size_cnv_threshold.bed.gz
# processed:   notinHG001_genomespecific_RTG_PG_v3.3.2_SVs_alldifficultregions.bed.gz
# processed:   notinHG002_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz
# processed:   notinHG002_genomespecific_complexandSVs_alldifficultregions_v4.1.bed.gz
# processed:   notinalldifficultregions.bed.gz
# processed:   notinalllowmapandsegdupregions.bed.gz
# processed:   segdups_chr1_22_gte_10kb_identity_gte_990_segdups_counts_gt_5.bed.gz
# processed:   union_HG002_CCS_15kb_20kb_merged_ONT_1000_window_size_combined_elliptical_outlier_threshold.bed.gz

# %% [markdown]
# #### GRCh38

# %%
##Some input files were zipped and others were not.  This is to check if file is zipped and if not then zip.

date
for f in ${INPUT38batch2}/original_files/*
do
OUTFILE=${INPUT38batch2}/$( basename ${f})

if [[ $f == *.bed ]] 
then
    echo "bgzipped: "$( basename ${f})
    bgzip < $f > ${OUTFILE}.gz
else
     cp $f ${INPUT38batch2}/$( basename ${f})
     echo "already zipped: "$( basename ${f})
fi
done
# Out:
# Wed Jan 22 16:40:25 EST 2020
# bgzipped: GCA_000001405.15_GRCh38_no_alt_plus_hs38d1_analysis_set_REF_N_slop_15kb.bed
# already zipped: GRCh38_HG002_genomespecific_CNVsandSVs_v4.1.bed.gz
# already zipped: GRCh38_alldifficultregions.bed.gz
# already zipped: GRCh38_alllowmapandsegdupregions.bed.gz
# bgzipped: GRCh38_mrcanavar_intersect_ccs_1000_window_size_cnv_threshold_intersect_ont_1000_window_size_cnv_threshold.bed
# already zipped: GRCh38_notinalldifficultregions.bed.gz
# already zipped: GRCh38_notinalllowmapandsegdupregions.bed.gz
# bgzipped: GRCh38_union_HG002_CCS_15kb_20kb_merged_ONT_1000_window_size_combined_elliptical_outlier_threshold.bed
# already zipped: HG001_genomespecific_RTG_PG_v3.3.2_SVs_alldifficultregions.bed.gz
# bgzipped: HG002_GRCh38_1_22_v4.1_draft_benchmark_comphetindel10bp_slop50.bed
# bgzipped: HG002_GRCh38_1_22_v4.1_draft_benchmark_comphetsnp10bp_slop50.bed
# bgzipped: HG002_GRCh38_1_22_v4.1_draft_benchmark_complexindel10bp_slop50.bed
# bgzipped: HG002_GRCh38_1_22_v4.1_draft_benchmark_othercomplexwithin10bp_slop50.bed
# bgzipped: HG002_GRCh38_1_22_v4.1_draft_benchmark_snpswithin10bp_slop50.bed
# already zipped: HG002_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz
# already zipped: HG002_genomespecific_complexandSVs_alldifficultregions_v4.1.bed.gz
# already zipped: HG002_genomespecific_complexandSVs_v4.1.bed.gz
# already zipped: HG003_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz
# already zipped: HG004_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz
# already zipped: HG005_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz
# bgzipped: HG2_SKor_TrioONTCanu_intersect_HG2_SKor_TrioONTFlye_intersect_HG2_SKor_CCS15_gt10kb_GRCh38.bed
# bgzipped: MHC_GRCh38.bed
# bgzipped: SVMergeInversions.GRCh38.120519.clustered_slop150_chr1_22.bed
# bgzipped: expanded_150_GRCh38_remapped_HG002_SVs_Tier1plusTier2_v0.6.1.bed
# bgzipped: hg38.contigs.1-22.lt_500kb.bed
# bgzipped: hg38.rmsk.L1H_gt500.bed
# bgzipped: hg38.segdups_chr1-22_gte_10kb_identity_gte_990_segdups_counts_gt_5.bed
# bgzipped: hg38.vdj.bed
# already zipped: notinHG001_genomespecific_RTG_PG_v3.3.2_SVs_alldifficultregions.bed.gz
# already zipped: notinHG002_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz
# already zipped: notinHG002_genomespecific_complexandSVs_alldifficultregions_v4.1.bed.gz
# already zipped: notinHG003_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz
# already zipped: notinHG004_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz
# already zipped: notinHG005_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz

# %%
date
bedtools --version 

for f in ${INPUT38batch2}*.gz
do
    OUTFILE=${OUTPUT38}/$( basename ${f})
    
    gzcat $f |
    sed 's/^chr//'|
    sed 's/^X/23/;s/^Y/24/'|
    grep -Ev '^M|^MT|^[0-9][0-9]_|^[0-9]_|^[0-9]\||^[0-9][0-9]\||^Un|^HS'|
    sort -k1,1n -k2,2n -k3,3n  |
    mergeBed -i stdin |
	sed 's/^23/X/;s/^24/Y/' |
    sed 's/^[a-zA-Z0-9_]/chr&/'|
    subtractBed -a stdin -b ${refNs}gap_38_1thruY_sorted_merged.bed | 
	subtractBed -a stdin -b ${refNs}PSA_Y_GRCh38.bed | 
    cat header.txt - |  
 	bgzip > ${OUTFILE}
    echo "processed:  " $( basename ${f})
    md5 ${OUTFILE} >> GRCh38_stratificationBEDs_for_Github_md5s.txt
    
done
# Out:
# Wed Jan 22 17:05:49 EST 2020
# bedtools v2.29.1
# processed:   GCA_000001405.15_GRCh38_no_alt_plus_hs38d1_analysis_set_REF_N_slop_15kb.bed.gz
# processed:   GRCh38_HG002_genomespecific_CNVsandSVs_v4.1.bed.gz
# processed:   GRCh38_alldifficultregions.bed.gz
# processed:   GRCh38_alllowmapandsegdupregions.bed.gz
# processed:   GRCh38_mrcanavar_intersect_ccs_1000_window_size_cnv_threshold_intersect_ont_1000_window_size_cnv_threshold.bed.gz
# processed:   GRCh38_notinalldifficultregions.bed.gz
# processed:   GRCh38_notinalllowmapandsegdupregions.bed.gz
# processed:   GRCh38_union_HG002_CCS_15kb_20kb_merged_ONT_1000_window_size_combined_elliptical_outlier_threshold.bed.gz
# processed:   HG001_genomespecific_RTG_PG_v3.3.2_SVs_alldifficultregions.bed.gz
# processed:   HG002_GRCh38_1_22_v4.1_draft_benchmark_comphetindel10bp_slop50.bed.gz
# processed:   HG002_GRCh38_1_22_v4.1_draft_benchmark_comphetsnp10bp_slop50.bed.gz
# processed:   HG002_GRCh38_1_22_v4.1_draft_benchmark_complexindel10bp_slop50.bed.gz
# processed:   HG002_GRCh38_1_22_v4.1_draft_benchmark_othercomplexwithin10bp_slop50.bed.gz
# processed:   HG002_GRCh38_1_22_v4.1_draft_benchmark_snpswithin10bp_slop50.bed.gz
# processed:   HG002_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz
# processed:   HG002_genomespecific_complexandSVs_alldifficultregions_v4.1.bed.gz
# processed:   HG002_genomespecific_complexandSVs_v4.1.bed.gz
# processed:   HG003_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz
# processed:   HG004_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz
# processed:   HG005_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz
# processed:   HG2_SKor_TrioONTCanu_intersect_HG2_SKor_TrioONTFlye_intersect_HG2_SKor_CCS15_gt10kb_GRCh38.bed.gz
# processed:   MHC_GRCh38.bed.gz
# processed:   SVMergeInversions.GRCh38.120519.clustered_slop150_chr1_22.bed.gz
# processed:   expanded_150_GRCh38_remapped_HG002_SVs_Tier1plusTier2_v0.6.1.bed.gz
# processed:   hg38.contigs.1-22.lt_500kb.bed.gz
# processed:   hg38.rmsk.L1H_gt500.bed.gz
# processed:   hg38.segdups_chr1-22_gte_10kb_identity_gte_990_segdups_counts_gt_5.bed.gz
# processed:   hg38.vdj.bed.gz
# processed:   notinHG001_genomespecific_RTG_PG_v3.3.2_SVs_alldifficultregions.bed.gz
# processed:   notinHG002_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz
# processed:   notinHG002_genomespecific_complexandSVs_alldifficultregions_v4.1.bed.gz
# processed:   notinHG003_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz
# processed:   notinHG004_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz
# processed:   notinHG005_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz

# %% [markdown]
# ## Prepare third batch of files
#
# These files are ones Justin had prepared for the previous (second) batch however I missed copying them over.

# %%
date
WKDIR=/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/
ckzip38=${WKDIR}GRCh38/newfiles_from_JZ_for_processing/original_files/added_012320/
ckzip37=${WKDIR}GRCh37/newfiles_from_JZ_for_processing/original_files/added_012320/
INPUT38batch3=${WKDIR}GRCh38/newfiles_from_JZ_for_processing/third_batch/
INPUT37batch3=${WKDIR}GRCh37/newfiles_from_JZ_for_processing/third_batch/
OUTPUT38=${WKDIR}GRCh38/sorted_merged_noNs/
OUTPUT37=${WKDIR}GRCh37/sorted_merged_noNs/
refNs=${WKDIR}refNs/
# Out:
# Fri Jan 24 13:11:33 EST 2020

# %% [markdown]
# #### GRCh37

# %%
##Some input files were zipped and others were not.  This is to check if file is zipped and if not then zip.

date
for f in ${ckzip37}/*
do
OUTFILE=${INPUT37batch3}/$( basename ${f})

if [[ $f == *.bed ]] 
then
    echo "bgzipped: "$( basename ${f})
    bgzip < $f > ${OUTFILE}.gz
else
     cp $f ${INPUT37batch3}/$( basename ${f})
     echo "already zipped: "$( basename ${f})
fi
done
# Out:
# Fri Jan 24 13:11:38 EST 2020
# already zipped: HG001_genomespecific_complexandSVs_v3.3.2_PG_RTG.bed.gz
# already zipped: HG002_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz
# already zipped: HG002_genomespecific_complexandSVs_v3.3.2.bed.gz
# already zipped: HG003_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz
# already zipped: HG003_genomespecific_complexandSVs_v3.3.2.bed.gz
# already zipped: HG004_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz
# already zipped: HG004_genomespecific_complexandSVs_v3.3.2.bed.gz
# already zipped: HG005_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz
# already zipped: HG005_genomespecific_complexandSVs_v3.3.2.bed.gz
# already zipped: notinHG002_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz
# already zipped: notinHG003_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz
# already zipped: notinHG004_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz
# already zipped: notinHG005_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz

# %%
date
bedtools --version 

for f in ${INPUT37batch3}*.gz
do
    OUTFILE=${OUTPUT37}/$( basename ${f})
    
	gzcat $f |
    sed 's/^chr//'|
    sed 's/^X/23/;s/^Y/24/'|
    grep -Ev '^M|^MT|^[0-9][0-9]_|^[0-9]_|^[0-9]\||^[0-9][0-9]\||^Un|^HS'|
    sort -k1,1n -k2,2n -k3,3n  |
    mergeBed -i stdin |
	sed 's/^23/X/;s/^24/Y/' |
    subtractBed -a stdin -b ${refNs}hg19.gap_1thruY_sorted_merged.bed | 
	subtractBed -a stdin -b ${refNs}PSA_Y_hg19.bed | 
    cat header.txt - | 
 	bgzip > ${OUTFILE}
     echo "processed:  " $( basename ${f})
    md5 ${OUTFILE} >> GRCh37_stratificationBEDs_for_Github_md5s.txt
    
done
# Out:
# Fri Jan 24 13:11:47 EST 2020
# bedtools v2.29.1
# processed:   HG001_genomespecific_complexandSVs_v3.3.2_PG_RTG.bed.gz
# processed:   HG002_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz
# processed:   HG002_genomespecific_complexandSVs_v3.3.2.bed.gz
# processed:   HG003_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz
# processed:   HG003_genomespecific_complexandSVs_v3.3.2.bed.gz
# processed:   HG004_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz
# processed:   HG004_genomespecific_complexandSVs_v3.3.2.bed.gz
# processed:   HG005_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz
# processed:   HG005_genomespecific_complexandSVs_v3.3.2.bed.gz
# processed:   notinHG002_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz
# processed:   notinHG003_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz
# processed:   notinHG004_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz
# processed:   notinHG005_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz

# %% [markdown]
# #### GRCh38

# %%
##Some input files were zipped and others were not.  This is to check if file is zipped and if not then zip.

date
for f in ${ckzip38}/*
do
OUTFILE=${INPUT38batch3}/$( basename ${f})

if [[ $f == *.bed ]] 
then
    echo "bgzipped: "$( basename ${f})
    bgzip < $f > ${OUTFILE}.gz
else
     cp $f ${INPUT38batch3}/$( basename ${f})
     echo "already zipped: "$( basename ${f})
fi
done
# Out:
# Fri Jan 24 13:24:38 EST 2020
# already zipped: GRCh38_allOtherDifficultregions.bed.gz
# already zipped: GRCh38_remapped_HG001_genomespecific_complexandSVs_v3.3.2_PG_RTG.bed.gz
# already zipped: GRCh38_remapped_HG002_genomespecific_complexandSVs_v3.3.2.bed.gz
# already zipped: GRCh38_remapped_HG003_genomespecific_complexandSVs_v3.3.2.bed.gz
# already zipped: GRCh38_remapped_HG004_genomespecific_complexandSVs_v3.3.2.bed.gz
# already zipped: GRCh38_remapped_HG005_genomespecific_complexandSVs_v3.3.2.bed.gz

# %%
date
bedtools --version 

for f in ${INPUT38batch3}*.gz
do
    OUTFILE=${OUTPUT38}/$( basename ${f})
    
    gzcat $f |
    sed 's/^chr//'|
    sed 's/^X/23/;s/^Y/24/'|
    grep -Ev '^M|^MT|^[0-9][0-9]_|^[0-9]_|^[0-9]\||^[0-9][0-9]\||^Un|^HS'|
    sort -k1,1n -k2,2n -k3,3n  |
    mergeBed -i stdin |
	sed 's/^23/X/;s/^24/Y/' |
    sed 's/^[a-zA-Z0-9_]/chr&/'|
    subtractBed -a stdin -b ${refNs}gap_38_1thruY_sorted_merged.bed | 
	subtractBed -a stdin -b ${refNs}PSA_Y_GRCh38.bed | 
    cat header.txt - |  
 	bgzip > ${OUTFILE}
    echo "processed:  " $( basename ${f})
    md5 ${OUTFILE} >> GRCh38_stratificationBEDs_for_Github_md5s.txt
    
done
# Out:
# Fri Jan 24 13:24:48 EST 2020
# bedtools v2.29.1
# processed:   GRCh38_allOtherDifficultregions.bed.gz
# processed:   GRCh38_remapped_HG001_genomespecific_complexandSVs_v3.3.2_PG_RTG.bed.gz
# processed:   GRCh38_remapped_HG002_genomespecific_complexandSVs_v3.3.2.bed.gz
# processed:   GRCh38_remapped_HG003_genomespecific_complexandSVs_v3.3.2.bed.gz
# processed:   GRCh38_remapped_HG004_genomespecific_complexandSVs_v3.3.2.bed.gz
# processed:   GRCh38_remapped_HG005_genomespecific_complexandSVs_v3.3.2.bed.gz

# %% [markdown]
# ## 1/30/20 Reprocess HG002_GRCh38_1_22_v4.1_draft_benchmark_othercomplexwithin10bp_slop50.bed
# After plotting coverage for  the prior version (in second batch) HG002_GRCh38_1_22_v4.1_draft_benchmark_othercomplexwithin10bp_slop50.bed it was noticed that coverage of GRCh38 was significantly higher than GRCh37.  JZ noticed he had a problem with the preparation of the original file so he remade.  The 1/30/20 file will replace any previous versions of this file.

# %%
date
WKDIR=/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/
ckzip38=${WKDIR}GRCh38/newfiles_from_JZ_for_processing/original_files/added_013020/
INPUT38batch2=${WKDIR}GRCh38/newfiles_from_JZ_for_processing/
OUTPUT38=${WKDIR}GRCh38/sorted_merged_noNs/second_batch_from_JZ/
refNs=${WKDIR}refNs/
# Out:
# Fri Jan 31 10:03:20 EST 2020

# %%
date
for f in ${ckzip38}/*
do
OUTFILE=${INPUT38batch2}/$( basename ${f})

if [[ $f == *.bed ]] 
then
    echo "bgzipped: "$( basename ${f})
    bgzip < $f > ${OUTFILE}.gz
else
     cp $f ${INPUT38batch2}/$( basename ${f})
     echo "already zipped: "$( basename ${f})
fi
done
# Out:
# Fri Jan 31 10:03:57 EST 2020
# bgzipped: HG002_GRCh38_1_22_v4.1_draft_benchmark_othercomplexwithin10bp_slop50.bed

# %%
date
bedtools --version 

    OUTFILE=${OUTPUT38}/$( basename /Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/newfiles_from_JZ_for_processing/HG002_GRCh38_1_22_v4.1_draft_benchmark_othercomplexwithin10bp_slop50.bed.gz)
    
    gzcat /Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/newfiles_from_JZ_for_processing/HG002_GRCh38_1_22_v4.1_draft_benchmark_othercomplexwithin10bp_slop50.bed.gz |
    sed 's/^chr//'|
    sed 's/^X/23/;s/^Y/24/'|
    grep -Ev '^M|^MT|^[0-9][0-9]_|^[0-9]_|^[0-9]\||^[0-9][0-9]\||^Un|^HS'|
    sort -k1,1n -k2,2n -k3,3n  |
    mergeBed -i stdin |
	sed 's/^23/X/;s/^24/Y/' |
    sed 's/^[a-zA-Z0-9_]/chr&/'|
    subtractBed -a stdin -b ${refNs}gap_38_1thruY_sorted_merged.bed | 
	subtractBed -a stdin -b ${refNs}PSA_Y_GRCh38.bed | 
    cat header.txt - |  
 	bgzip > ${OUTFILE}
    echo "processed:  " $( basename ${f})
    md5 ${OUTFILE} >> GRCh38_stratificationBEDs_for_Github_md5s.txt
# Out:
# Fri Jan 31 10:04:50 EST 2020
# bedtools v2.29.1
# processed:   HG002_GRCh38_1_22_v4.1_draft_benchmark_othercomplexwithin10bp_slop50.bed

# %% [markdown]
# ##  2/11/20 JZ revised union files to incorporate decoy (mm-2-merged.bed)
# JZ realized he did not use the decoy file (mm-2-merged.bed) in his union files.  He re-ran Merge_difficult_regions.sh for the following files.  Note: alllowmapandsegdupregions.bed.gz and notinalllowmapandsegdupregions.bed.gz did not change but were re-run as they were part of the script.

# %%
date
WKDIR=/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/
ckzip37=${WKDIR}GRCh37/newfiles_from_JZ_for_processing/original_files/revised_021120/
INPUT37_021120=${WKDIR}GRCh37/newfiles_from_JZ_for_processing/revised_021120/
OUTPUT37_021120=${WKDIR}GRCh37/sorted_merged_noNs/revised_021120/
refNs=${WKDIR}refNs/
# Out:
# Tue Feb 11 15:34:38 EST 2020

# %%
##Some input files were zipped and others were not.  This is to check if file is zipped and if not then zip.

date
for f in ${ckzip37}/*
do
OUTFILE=${INPUT37_021120}/$( basename ${f})

if [[ $f == *.bed ]] 
then
    echo "bgzipped: "$( basename ${f})
    bgzip < $f > ${OUTFILE}.gz
else
     cp $f ${INPUT37_021120}/$( basename ${f})
     echo "already zipped: "$( basename ${f})
fi
done
# Out:
# Tue Feb 11 15:36:53 EST 2020
# already zipped: HG001_genomespecific_RTG_PG_v3.3.2_SVs_alldifficultregions.bed.gz
# already zipped: HG002_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz
# already zipped: HG002_genomespecific_complexandSVs_alldifficultregions_v4.1.bed.gz
# already zipped: HG003_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz
# already zipped: HG004_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz
# already zipped: HG005_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz
# already zipped: allOtherDifficultregions.bed.gz
# already zipped: alldifficultregions.bed.gz
# already zipped: alllowmapandsegdupregions.bed.gz
# bgzipped: mm-2-merged.bed
# already zipped: notinHG001_genomespecific_RTG_PG_v3.3.2_SVs_alldifficultregions.bed.gz
# already zipped: notinHG002_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz
# already zipped: notinHG002_genomespecific_complexandSVs_alldifficultregions_v4.1.bed.gz
# already zipped: notinHG003_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz
# already zipped: notinHG004_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz
# already zipped: notinHG005_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz
# already zipped: notinalldifficultregions.bed.gz
# already zipped: notinalllowmapandsegdupregions.bed.gz

# %%
date
bedtools --version 

for f in ${INPUT37_021120}*.gz
do
    OUTFILE=${OUTPUT37_021120}/$( basename ${f})
    
	gzcat $f |
    sed 's/^chr//'|
    sed 's/^X/23/;s/^Y/24/'|
    grep -Ev '^M|^MT|^[0-9][0-9]_|^[0-9]_|^[0-9]\||^[0-9][0-9]\||^Un|^HS'|
    sort -k1,1n -k2,2n -k3,3n  |
    mergeBed -i stdin |
	sed 's/^23/X/;s/^24/Y/' |
    subtractBed -a stdin -b ${refNs}hg19.gap_1thruY_sorted_merged.bed | 
	subtractBed -a stdin -b ${refNs}PSA_Y_hg19.bed | 
    cat ${WKDIR}header.txt - | 
 	bgzip > ${OUTFILE}
     echo "processed:  " $( basename ${f})
    md5 ${OUTFILE} >> ${WKDIR}GRCh37_stratificationBEDs_for_Github_md5s.txt
    
done
# Out:
# Tue Feb 11 15:38:04 EST 2020
# bedtools v2.29.1
# processed:   HG001_genomespecific_RTG_PG_v3.3.2_SVs_alldifficultregions.bed.gz
# processed:   HG002_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz
# processed:   HG002_genomespecific_complexandSVs_alldifficultregions_v4.1.bed.gz
# processed:   HG003_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz
# processed:   HG004_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz
# processed:   HG005_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz
# processed:   allOtherDifficultregions.bed.gz
# processed:   alldifficultregions.bed.gz
# processed:   alllowmapandsegdupregions.bed.gz
# processed:   mm-2-merged.bed.gz
# processed:   notinHG001_genomespecific_RTG_PG_v3.3.2_SVs_alldifficultregions.bed.gz
# processed:   notinHG002_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz
# processed:   notinHG002_genomespecific_complexandSVs_alldifficultregions_v4.1.bed.gz
# processed:   notinHG003_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz
# processed:   notinHG004_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz
# processed:   notinHG005_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz
# processed:   notinalldifficultregions.bed.gz
# processed:   notinalllowmapandsegdupregions.bed.gz

# %% [markdown]
# ## 2/21/20 Revised mappability and functional region files
# Nate revised some of the mappability and functional region files.  Previous versions of these files will be removed.

# %%
date
WKDIR=/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/
INPUT37_022120=${WKDIR}GRCh37/NDO_revised_022120/
OUTPUT37_022120=${WKDIR}GRCh37/sorted_merged_noNs/revised_022120/
refNs=${WKDIR}refNs/
# Out:
# Fri Feb 21 14:05:29 EST 2020

# %%
date
bedtools --version 

for f in ${INPUT37_022120}*.gz
do
    OUTFILE=${OUTPUT37_022120}/$( basename ${f})
    
	gzcat $f |
    sed 's/^chr//'|
    sed 's/^X/23/;s/^Y/24/'|
    grep -Ev '^M|^MT|^[0-9][0-9]_|^[0-9]_|^[0-9]\||^[0-9][0-9]\||^Un|^HS'|
    sort -k1,1n -k2,2n -k3,3n  |
    mergeBed -i stdin |
	sed 's/^23/X/;s/^24/Y/' |
    subtractBed -a stdin -b ${refNs}hg19.gap_1thruY_sorted_merged.bed | 
	subtractBed -a stdin -b ${refNs}PSA_Y_hg19.bed | 
    cat ${WKDIR}header.txt - | 
 	bgzip > ${OUTFILE}
     echo "processed:  " $( basename ${f})
    md5 ${OUTFILE} >> ${WKDIR}GRCh37_stratificationBEDs_for_Github_md5s.txt
    
done
# Out:
# Fri Feb 21 14:06:55 EST 2020
# bedtools v2.29.1
# processed:   GRCh37_refseq_cds_merged.bed.gz
# processed:   lowmappabilityall.bed.gz
# processed:   notin_GRCh37_refseq_cds_merged.bed.gz
# processed:   notinlowmappabilityall.bed.gz

# %% [markdown]
# ### MD5s

# %%
date
WKDIR=/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/
#original files from NAS
#first batch- all were zipped to begin with
INPUT38=${WKDIR}GRCh38/
INPUT37=${WKDIR}GRCh37/
#second batch 
INPUT38batch2ORG=${WKDIR}GRCh38/newfiles_from_JZ_for_processing/original_files/
INPUT37batch2ORG=${WKDIR}GRCh37/newfiles_from_JZ_for_processing/original_files/
#third batch
ckzip38=${INPUT38batch2ORG}/added_012320/
ckzip38revised=${INPUT38batch2ORG}/added_013020/
ckzip37=${INPUT37batch2ORG}/added_012320/
ckzip37_revised_021120=${INPUT37batch2ORG}/revised_021120/
#022120 revised
INPUT37_022120=${INPUT37}/NDO_revised_022120/

#Script Output files
OUTPUT38=${WKDIR}GRCh38/sorted_merged_noNs/
OUTPUT38batch2=${WKDIR}GRCh38/sorted_merged_noNs/second_batch_from_JZ/
OUTPUT37=${WKDIR}GRCh37/sorted_merged_noNs/
OUTPUT37batch2=${WKDIR}GRCh37/sorted_merged_noNs/second_batch_from_JZ/
OUTPUT37_revised_021120=${WKDIR}GRCh37/sorted_merged_noNs/revised_021120/
OUTPUT37_revised_022120=${WKDIR}GRCh37/sorted_merged_noNs/revised_022120/
# Out:
# Fri Feb 21 14:27:54 EST 2020

# %% [markdown]
# #### GRCh37 original files
# these are files that Justin created and were transferred from NAS

# %%
date
echo "FIRST BATCH" 
for f in ${INPUT37}/*
do
md5 $f | tee -a GRCh37_stratificationBEDs_original_files_md5s.txt
done

echo "SECOND BATCH" 
for f in ${INPUT37batch2ORG}/*
do
md5 $f | tee -a GRCh37_stratificationBEDs_original_files_md5s.txt
done

echo "THIRD BATCH"
for f in ${ckzip37}/*
do
md5 $f | tee -a GRCh37_stratificationBEDs_original_files_md5s.txt
done

echo "revised 021120"
for f in ${ckzip37_revised_021120}/*
do
md5 $f | tee -a GRCh37_stratificationBEDs_original_files_md5s.txt
done

echo "revised 022120"
for f in ${INPUT37_022120}/*
do
md5 $f | tee -a GRCh37_stratificationBEDs_original_files_md5s.txt
done
# Out:
# Fri Feb 21 14:27:57 EST 2020
# FIRST BATCH
# md5: /Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37//ALL_GRCh37_sorted_merged_renamed_BEDs_for_GitHub: Is a directory
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37//AllHomopolymers_gt6bp_imperfectgt10bp_slop5.bed.gz) = 1349fd487bb1e3e7ba39474a4ead2097
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37//AllTandemRepeats_201to10000bp_slop5.bed.gz) = 46ac79107aa5945bf92f44820b89695f
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37//AllTandemRepeats_51to200bp_slop5.bed.gz) = 4b1f2b0896454c1f80f21c124049ee64
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37//AllTandemRepeats_gt10000bp_slop5.bed.gz) = 056c8a67da06edb71b06f82b7a14b0d9
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37//AllTandemRepeats_gt100bp_slop5.bed.gz) = 26732e53a083c3d3ca18bf5a240468e8
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37//AllTandemRepeats_lt51bp_slop5.bed.gz) = 7024841c9fe1b1a2af34f8305252b00a
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37//AllTandemRepeatsandHomopolymers_slop5.bed.gz) = 255909ca44604e541baf8b158eb2f2a7
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37//BadPromoters_gb-2013-14-5-r51-s1.bed.gz) = d9059384404e8f6218fa4d271f008865
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37//GRCh37_chainSelf_sorted_merged.bed.gz) = a997899308d2343150ae7cfc1cf6d4af
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37//GRCh37_chainSelf_sorted_merged_gt10kb.bed.gz) = 54026470ca8fc602648356db063e34ba
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37//GRCh37_notinchainSelf_sorted_merged.bed.gz) = 78724aeeb4977a080695010062d2a29a
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37//GRCh37_notinchainSelf_sorted_merged_gt10kb.bed.gz) = e03447454eaa5b64b225547c7d819662
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37//HG001_GRCh37_GIAB_highconf_CG-IllFB-IllGATKHC-Ion-10X-SOLID_CHROM1-X_v.3.3.2_highconf_RTGandPGphasetransfer_comphetindel10bp_slop50.bed.gz) = 3860a898012a5a3f9528571c5b453b60
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37//HG001_GRCh37_GIAB_highconf_CG-IllFB-IllGATKHC-Ion-10X-SOLID_CHROM1-X_v.3.3.2_highconf_RTGandPGphasetransfer_comphetsnp10bp_slop50.bed.gz) = f17b096eeb4a2ca02df709629e9019f1
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37//HG001_GRCh37_GIAB_highconf_CG-IllFB-IllGATKHC-Ion-10X-SOLID_CHROM1-X_v.3.3.2_highconf_RTGandPGphasetransfer_complexindel10bp_slop50.bed.gz) = 1dc7ff07dc91757f3de31f7ad7ed2274
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37//HG001_GRCh37_GIAB_highconf_CG-IllFB-IllGATKHC-Ion-10X-SOLID_CHROM1-X_v.3.3.2_highconf_RTGandPGphasetransfer_snpswithin10bp_slop50.bed.gz) = 3ac2afc49c65992305a5d05e68ab5467
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37//HG002_GIAB_highconf_IllFB-IllGATKHC-CG-Ion-Solid_CHROM1-22_v3.2.2_highconf_geno2haplo_compoundhet_slop50.bed.gz) = 09e46a242086f36261db6ba8c96a4982
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37//HG002_GIAB_highconf_IllFB-IllGATKHC-CG-Ion-Solid_CHROM1-22_v3.2.2_highconf_varswithin50bp.bed.gz) = 8077638b46ce438a726cdb24df5cb0ab
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37//HG002_GRCh37_GIAB_highconf_CG-IllFB-IllGATKHC-Ion-10X-SOLID_CHROM1-22_v.3.3.2_highconf_triophased_comphetindel10bp_slop50.bed.gz) = b83747629a3dbf6ee369179df307eb5d
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37//HG002_GRCh37_GIAB_highconf_CG-IllFB-IllGATKHC-Ion-10X-SOLID_CHROM1-22_v.3.3.2_highconf_triophased_comphetsnp10bp_slop50.bed.gz) = ce4c9a6b69ed8196fa906f528b55ce23
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37//HG002_GRCh37_GIAB_highconf_CG-IllFB-IllGATKHC-Ion-10X-SOLID_CHROM1-22_v.3.3.2_highconf_triophased_complexindel10bp_slop50.bed.gz) = 6caa104184b0a070460a3f5c9e26f4fa
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37//HG002_GRCh37_GIAB_highconf_CG-IllFB-IllGATKHC-Ion-10X-SOLID_CHROM1-22_v.3.3.2_highconf_triophased_snpswithin10bp_slop50.bed.g
inHG005_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz) = f2954c2458df7cd9f9ef4fd49546b4ce
# revised 021120
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/newfiles_from_JZ_for_processing/original_files//revised_021120//HG001_genomespecific_RTG_PG_v3.3.2_SVs_alldifficultregions.bed.gz) = 414200cf59d80556f5ac9423314c443b
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/newfiles_from_JZ_for_processing/original_files//revised_021120//HG002_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz) = 65617ec02382e721417937ad83944eaa
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/newfiles_from_JZ_for_processing/original_files//revised_021120//HG002_genomespecific_complexandSVs_alldifficultregions_v4.1.bed.gz) = cc441f6619be36a7a4bb5d505cb503d6
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/newfiles_from_JZ_for_processing/original_files//revised_021120//HG003_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz) = 7bf3cddb1a7843a2702235564b8918ad
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/newfiles_from_JZ_for_processing/original_files//revised_021120//HG004_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz) = 2091cafc86c236a95a4f736ad9a7cb09
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/newfiles_from_JZ_for_processing/original_files//revised_021120//HG005_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz) = 49af1e3de6b9f5503ab5b8dd70cc815c
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/newfiles_from_JZ_for_processing/original_files//revised_021120//allOtherDifficultregions.bed.gz) = d8a908ec10083ccb99e1a603d3553714
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/newfiles_from_JZ_for_processing/original_files//revised_021120//alldifficultregions.bed.gz) = d11d8a11ad4080c70ef81abbd98bfe4a
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/newfiles_from_JZ_for_processing/original_files//revised_021120//alllowmapandsegdupregions.bed.gz) = 4c085421c509cd248fbf4bccc5fa48d3
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/newfiles_from_JZ_for_processing/original_files//revised_021120//mm-2-merged.bed) = bacd5d2e2b9963c3c9253694b5a1f395
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/newfiles_from_JZ_for_processing/original_files//revised_021120//notinHG001_genomespecific_RTG_PG_v3.3.2_SVs_alldifficultregions.bed.gz) = a664e386c573c2294e210b3a18866f6e
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/newfiles_from_JZ_for_processing/original_files//revised_021120//notinHG002_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz) = 769e8f91fdd9d810ad02cc93bd2f145b
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/newfiles_from_JZ_for_processing/original_files//revised_021120//notinHG002_genomespecific_complexandSVs_alldifficultregions_v4.1.bed.gz) = 7ab9377ebc64083fb11e7e17a45af388
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/newfiles_from_JZ_for_processing/original_files//revised_021120//notinHG003_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz) = c718202af111adec91b5c183a6374890
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/newfiles_from_JZ_for_processing/original_files//revised_021120//notinHG004_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz) = 4294a7555fb82ba79d968671835a213f
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/newfiles_from_JZ_for_processing/original_files//revised_021120//notinHG005_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz) = e69a047d8f66c8ad0066eb80b7dc7d76
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/newfiles_from_JZ_for_processing/original_files//revised_021120//notinalldifficultregions.bed.gz) = 5a5cf16d744a5d287a700c452c4e4b3a
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/newfiles_from_JZ_for_processing/original_files//revised_021120//notinalllowmapandsegdupregions.bed.gz) = 89e7b4592dde3ff73f453ba97cae65fe
# revised 022120
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37//NDO_revised_022120//GRCh37_refseq_cds_merged.bed.gz) = 4c714b0494a2f9fdf0a6a3f9112a9dfa
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37//NDO_revised_022120//lowmappabilityall.bed.gz) = 42e71a16584d7def2910d8e3c2d36618
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37//NDO_revised_022120//notin_GRCh37_refseq_cds_merged.bed.gz) = 20eaae32105a2bb75e2d61d626baa682
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37//NDO_revised_022120//notinlowmappabilityall.bed.gz) = 0113a85535df08c68b1b760ac3df250f

# %% [markdown]
# #### GRCh38 original files
# these are files Justin created and transferred from NAS

# %%
date
echo "FIRST BATCH"
for f in ${INPUT38}/*
do
md5 $f | tee -a GRCh38_stratificationBEDs_original_files_md5s.txt
done

echo "SECOND BATCH"
for f in ${INPUT38batch2ORG}/*
do
md5 $f | tee -a GRCh38_stratificationBEDs_original_files_md5s.txt
done

echo "THIRD BATCH"
for f in ${ckzip38}/*
do
md5 $f | tee -a GRCh38_stratificationBEDs_original_files_md5s.txt
done
# Out:
# Tue Feb 11 15:56:09 EST 2020
# FIRST BATCH
# md5: /Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38//ALL_GRCh38_sorted_merged_renamed_BEDs_for_GitHub: Is a directory
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38//GRCh38_AllHomopolymers_gt6bp_imperfectgt10bp_slop5.bed.gz) = d6d3eb30e09c3d2ed2f2689dd5f8d3ec
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38//GRCh38_AllTandemRepeats_201to10000bp_slop5.bed.gz) = acff62266d425b01e1762bf6d53c9582
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38//GRCh38_AllTandemRepeats_51to200bp_slop5.bed.gz) = 01ad1bc3b61c74dbdbd93e854f76b23b
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38//GRCh38_AllTandemRepeats_gt10000bp_slop5.bed.gz) = 86bd3b7ad00092d4bf03635aaef9573c
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38//GRCh38_AllTandemRepeats_gt100bp_slop5.bed.gz) = 04df230bf0b0346ea78949573966b132
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38//GRCh38_AllTandemRepeats_lt51bp_slop5.bed.gz) = a7c9358a6a17fe3e8b4037f0502d9d26
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38//GRCh38_AllTandemRepeatsandHomopolymers_slop5.bed.gz) = 21cb94f6fa230c43f480f7d41f44b6ee
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38//GRCh38_SimpleRepeat_diTR_11to50_slop5.bed.gz) = 7bf078b4e5cceb4cb05585fd4df0e21e
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38//GRCh38_SimpleRepeat_diTR_51to200_slop5.bed.gz) = 800f010de3d702a1e0a9ca83992f5ec6
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38//GRCh38_SimpleRepeat

# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/newfiles_from_JZ_for_processing/original_files//GRCh38_alllowmapandsegdupregions.bed.gz) = ac9064a8028dbd589e348f39608b2777
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/newfiles_from_JZ_for_processing/original_files//GRCh38_mrcanavar_intersect_ccs_1000_window_size_cnv_threshold_intersect_ont_1000_window_size_cnv_threshold.bed) = c48c3d87c7596d2e21d84dd44c4ab3e8
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/newfiles_from_JZ_for_processing/original_files//GRCh38_notinalldifficultregions.bed.gz) = 525f2a241a5a2f9c04ea590033f1edd6
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/newfiles_from_JZ_for_processing/original_files//GRCh38_notinalllowmapandsegdupregions.bed.gz) = 4cc74134530e4740f88886993f490c25
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/newfiles_from_JZ_for_processing/original_files//GRCh38_union_HG002_CCS_15kb_20kb_merged_ONT_1000_window_size_combined_elliptical_outlier_threshold.bed) = 1bbbda96eea36fc7e193fa78e8c27a9c
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/newfiles_from_JZ_for_processing/original_files//HG001_genomespecific_RTG_PG_v3.3.2_SVs_alldifficultregions.bed.gz) = 7f28e82d799ef31583336866b472965e
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/newfiles_from_JZ_for_processing/original_files//HG002_GRCh38_1_22_v4.1_draft_benchmark_comphetindel10bp_slop50.bed) = c25f6b48bbdebb7ad8a3251d2a225820
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/newfiles_from_JZ_for_processing/original_files//HG002_GRCh38_1_22_v4.1_draft_benchmark_comphetsnp10bp_slop50.bed) = de995c52717491c1bd82ef7b9f73cb2b
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/newfiles_from_JZ_for_processing/original_files//HG002_GRCh38_1_22_v4.1_draft_benchmark_complexindel10bp_slop50.bed) = 25737a7d73421a3e53b923af6d13aeea
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/newfiles_from_JZ_for_processing/original_files//HG002_GRCh38_1_22_v4.1_draft_benchmark_snpswithin10bp_slop50.bed) = 0dc7d40960cafcc36190cdc3df7feb76
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/newfiles_from_JZ_for_processing/original_files//HG002_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz) = f00340af7f9ae5524d10723bc8d9066c
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/newfiles_from_JZ_for_processing/original_files//HG002_genomespecific_complexandSVs_alldifficultregions_v4.1.bed.gz) = cd899f4e751c5cb84945083370be9ea2
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/newfiles_from_JZ_for_processing/original_files//HG002_genomespecific_complexandSVs_v4.1.bed.gz) = 9514dbee1456ecb61a48b637aef31021
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/newfiles_from_JZ_for_processing/original_files//HG003_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz) = 051fba76cf21bc9ff45776a3219467a3
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/newfiles_from_JZ_for_processing/original_files//HG004_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz) = 1b54bcb75c67bf52adafa6391fcf2325
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/newfiles_from_JZ_for_processing/original_files//HG005_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz) = 2279f5d59201eec6e9a78e21192a6f9f
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/newfiles_from_JZ_for_processing/original_files//HG2_SKor_TrioONTCanu_intersect_HG2_SKor_TrioONTFlye_intersect_HG2_SKor_CCS15_gt10kb_GRCh38.bed) = 71a91b430c3c42af4eb875ac8b14d55f
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/newfiles_from_JZ_for_processing/original_files//MHC_GRCh38.bed) = 3ad5379af2e4dfb8b9ebc1a1ddb06f36
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/newfiles_from_JZ_for_processing/original_files//SVMergeInversions.GRCh38.120519.clustered_slop150_chr1_22.bed) = a4f6626b50cfec06c3bad20b3576e2bc
# md5: /Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/newfiles_from_JZ_for_processing/original_files//added_012320: Is a directory
# md5: /Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/newfiles_from_JZ_for_processing/original_files//added_013020: Is a directory
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/newfiles_from_JZ_for_processing/original_files//expanded_150_GRCh38_remapped_HG002_SVs_Tier1plusTier2_v0.6.1.bed) = 293926454c8011c70a3c4d4452798e05
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/newfiles_from_JZ_for_processing/original_files//hg38.contigs.1-22.lt_500kb.bed) = 6cf08121fba946b88678e09f27489cff
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/newfiles_from_JZ_for_processing/original_files//hg38.rmsk.L1H_gt500.bed) = 653796f841d7cb0784973fc8853054db
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/newfiles_from_JZ_for_processing/original_files//hg38.segdups_chr1-22_gte_10kb_identity_gte_990_segdups_counts_gt_5.bed) = f7855c3f1b1c5b38b0a8c53f90f3cc42
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/newfiles_from_JZ_for_processing/original_files//hg38.vdj.bed) = 1bab265d76525c77dcb9dfc4c6291c38
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/newfiles_from_JZ_for_processing/original_files//notinHG001_genomespecific_RTG_PG_v3.3.2_SVs_alldifficultregions.bed.gz) = 840a17fbe3de6ceb7dc334b05decf551
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/newfiles_from_JZ_for_processing/original_files//notinHG002_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz) = 046b3dc146d6424fd015ad53a780c775
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/newfiles_from_JZ_for_processing/original_files//notinHG002_genomespecific_complexandSVs_alldifficultregions_v4.1.bed.gz) = a00c1a3506fcb096dac08635c30113c4
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/newfiles_from_JZ_for_processing/original_files//notinHG003_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz) = 69320267faa4f0366d2d616f176401c7
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/newfiles_from_JZ_for_processing/original_files//notinHG004_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz) = d99dab2fe7ac490ce976cb6ace0e04cb
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/newfiles_from_JZ_for_processing/original_files//notinHG005_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz) = e0368443c87debf25bffbb5d9a66f34b
# THIRD BATCH
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/newfiles_from_JZ_for_processing/original_files//added_012320//GRCh38_allOtherDifficultregions.bed.gz) = 2c22bfa2a3ffa4aa6fa4a65797762464
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/newfiles_from_JZ_for_processing/original_files//added_012320//GRCh38_remapped_HG001_genomespecific_complexandSVs_v3.3.2_PG_RTG.bed.gz) = 73268e279248b35df6c53c8fd2bd0033
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/newfiles_from_JZ_for_processing/original_files//added_012320//GRCh38_remapped_HG002_genomespecific_complexandSVs_v3.3.2.bed.gz) = 08b02ff89548c9114e08c6e18018681f
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/newfiles_from_JZ_for_processing/original_files//added_012320//GRCh38_remapped_HG003_genomespecific_complexandSVs_v3.3.2.bed.gz) = 3c50364e49b33248b3333ebd3e2cfd09
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/newfiles_from_JZ_for_processing/original_files//added_012320//GRCh38_remapped_HG004_genomespecific_complexandSVs_v3.3.2.bed.gz) = 8e240966467fadae554619bd984aae23
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/newfiles_from_JZ_for_processing/original_files//added_012320//GRCh38_remapped_HG005_genomespecific_complexandSVs_v3.3.2.bed.gz) = bb9ae66bc1f0a387501159eb90295e9b

# %% [markdown]
# #### GRCh37 ouput files
# files output from the "Prepare Stratification BEDs for GitHub" script

# %%
date
echo "FIRST BATCH"
for f in ${OUTPUT37}/*.gz
do
md5 $f
done

echo "SECOND BATCH"
for f in ${OUTPUT37batch2}/*.gz
do
md5 $f
done

echo "revised 021120"
for f in ${OUTPUT37_revised_021120}/*.gz
do
md5 $f
done

echo "revised 022120"
for f in ${OUTPUT37_revised_022120}/*.gz
do
md5 $f
done
# Out:
# Fri Feb 21 14:42:37 EST 2020
# FIRST BATCH
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs//AllHomopolymers_gt6bp_imperfectgt10bp_slop5.bed.gz)

# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs//SimpleRepeat_diTR_51to200_slop5.bed.gz) = 34e3d79d3543460adf5b800fefc479e7
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs//SimpleRepeat_diTR_gt200_slop5.bed.gz) = 90d6eb5716aaa28de01ead71420fb50e
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs//SimpleRepeat_homopolymer_4to6_slop5.bed.gz) = 24cc2057452c9df4a235f8f0af7eb46a
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs//SimpleRepeat_homopolymer_7to11_slop5.bed.gz) = 4ab2bf4eef862cc439d4fde273cab9e1
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs//SimpleRepeat_homopolymer_gt11_slop5.bed.gz) = b72496bcef4aafefd4d3b0a3b273fe7f
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs//SimpleRepeat_imperfecthomopolgt10_slop5.bed.gz) = 68fa1d4a20738175cd133e2348a44120
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs//SimpleRepeat_quadTR_20to50_slop5.bed.gz) = a48792470b895ea19da112b1a371e6b4
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs//SimpleRepeat_quadTR_51to200_slop5.bed.gz) = 4932e3bbd215ad91902085102610e4c1
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs//SimpleRepeat_quadTR_gt200_slop5.bed.gz) = aac094fcee3dca43630f6785be5d0376
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs//SimpleRepeat_triTR_15to50_slop5.bed.gz) = 23bb11bdc5e0c723b85a52c8ac278fac
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs//SimpleRepeat_triTR_51to200_slop5.bed.gz) = edb477752daf368090e5cd3968d4e078
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs//SimpleRepeat_triTR_gt200_slop5.bed.gz) = 5d1404f315a3641fe51b9ce655c929c0
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs//hg19.notinsegdups_sorted_merged.bed.gz) = 098935aa5464df81dceb40f7e6506a3c
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs//hg19.notinsegdups_sorted_merged_gt10kb.bed.gz) = 33c8ecaa6d9bcad7ab06b284dc9146ca
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs//hg19.segdups_sorted_merged.bed.gz) = 383beee3746ecb2e88bcedbdf7614dc6
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs//hg19.segdups_sorted_merged_gt10kb.bed.gz) = f9df5ec383dcecd853d3dd2966fe1e4e
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs//human_g1k_v37_gemmap_l100_m0_e0_nonuniq.sort.bed.gz) = 0f22fcfc59b211947f7ceecc3d7d0d91
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs//human_g1k_v37_gemmap_l100_m1_e0_nonuniq.sort.bed.gz) = 7653becf626d4cf0bb27dbfead7d1495
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs//human_g1k_v37_gemmap_l100_m2_e0_nonuniq.sort.bed.gz) = 1c6f02e5bf2f1511123912750514f66c
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs//human_g1k_v37_gemmap_l100_m2_e1_nonuniq.sort.bed.gz) = 1fb92376479032238e2a0f4774819513
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs//human_g1k_v37_gemmap_l125_m0_e0_nonuniq.sort.bed.gz) = f89d5652ff883905afd54130501f7db5
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs//human_g1k_v37_gemmap_l125_m1_e0_nonuniq.sort.bed.gz) = 2df7d79e22ef12f95daf2133ed4880e2
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs//human_g1k_v37_gemmap_l125_m2_e0_nonuniq.sort.bed.gz) = c89792542d24ca3b296ae7560f5898a4
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs//human_g1k_v37_gemmap_l125_m2_e1_nonuniq.sort.bed.gz) = c9ef0f69d7a47d99c21336a3ee9b7e67
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs//human_g1k_v37_gemmap_l150_m0_e0_nonuniq.sort.bed.gz) = 444678f037179798e777cbdd3c1237cf
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs//human_g1k_v37_gemmap_l150_m1_e0_nonuniq.sort.bed.gz) = 04e34f33b5abf30b0fee8c2ec11032d8
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs//human_g1k_v37_gemmap_l150_m2_e0_nonuniq.sort.bed.gz) = 0f539e38bc86b1890e4ea078059c07fe
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs//human_g1k_v37_gemmap_l150_m2_e1_nonuniq.sort.bed.gz) = 2ce4b38a614541c83eff9d43760b19f9
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs//human_g1k_v37_gemmap_l250_m0_e0_nonuniq.sort.bed.gz) = 3f89243deb75fe5b9a4cb62ad39cfaea
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs//human_g1k_v37_gemmap_l250_m1_e0_nonuniq.sort.bed.gz) = 67cf2b18cdeb371557750e90dba50cda
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs//human_g1k_v37_gemmap_l250_m2_e0_nonuniq.sort.bed.gz) = f96eb9228e4644330df7374e38b4263e
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs//human_g1k_v37_gemmap_l250_m2_e1_nonuniq.sort.bed.gz) = 469a429e1ca8823c25b4934593127147
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs//human_g1k_v37_l100_gc15_slop50.bed.gz) = 2af8802225ca5daf740fe00e9b0f57eb
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs//human_g1k_v37_l100_gc15to20_slop50.bed.gz) = 87ee652ac75b7b04842798e69c398fd3
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs//human_g1k_v37_l100_gc20to25_slop50.bed.gz) = 7e1a03bb15d8b62ae0fada6429226e0b
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs//human_g1k_v37_l100_gc25to30_slop50.bed.gz) = 56b254b1121eff88c1a80b853e3ad363
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs//human_g1k_v37_l100_gc30to55_slop50.bed.gz) = 68b1061979e8e00a8c5667332b96e953
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs//human_g1k_v37_l100_gc55to60_slop50.bed.gz) = 80ca5edc44b08426ef01da79c16111f7
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs//human_g1k_v37_l100_gc60to65_slop50.bed.gz) = 97224e78056fc862ab309b7030a03c65
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs//human_g1k_v37_l100_gc65to70_slop50.bed.gz) = 29e7a6473fb4c393dd4acee6f2287a09
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs//human_g1k_v37_l100_gc70to75_slop50.bed.gz) = 421fef1104933df1c7c602e51ddcdc6d
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs//human_g1k_v37_l100_gc75to80_slop50.bed.gz) = c64de93af3695ed102ac0d0400afb2d2
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs//human_g1k_v37_l100_gc80to85_slop50.bed.gz) = bb43c186e17955288be438a3640ad68f
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs//human_g1k_v37_l100_gc85_slop50.bed.gz) = f39d5870d5f6fa56efa95524c8e98a6d
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs//human_g1k_v37_l100_gclt25orgt65_slop50.bed.gz) = 8be64ae76451ce45deeff5a87f14deee
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs//human_g1k_v37_l100_gclt30orgt55_slop50.bed.gz) = 48353edc7d87f32f867af2916892541c
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs//notinAllHomopolymers_gt6bp_imperfectgt10bp_slop5.bed.gz) = 5a37dd0665aa8ee2170a42fbc1617fa4
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs//notinAllTandemRepeatsandHomopolymers_slop5.bed.gz) = 612e4209fd3cb5d360795ec3029e65b7
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs//siren_similarRegions_dist1.bed.gz) = 3e9a7113e47a897783e7acfb6430b3c1
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs//sp_v37.7.3.NA12878_comphetindel10bp_slop50.bed.gz) = a460c37e9fd38a0101ff79176812b843
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs//sp_v37.7.3.NA12878_comphetsnp10bp_slop50.bed.gz) = a90bb7bda6697f8edb6906d6dd926dd2
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs//sp_v37.7.3.NA12878_complexindel10bp_slop50.bed.gz) = 6bd2cbb8a2660cc90562823dd9826aae
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs//sp_v37.7.3.NA12878_snpswithin10bp_slop50.bed.gz) = 4420589e747ea6d50043800177d8df5c
# SECOND BATCH
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs/second_batch_from_JZ//HG001_genomespecific_complexandSVs_v3.3.2_PG_RTG.bed.gz) = 2c7642c21d9d83e9a895588403a3c493
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs/second_batch_from_JZ//HG002_GRCh37_1_22_v4.1_draft_benchmark_comphetindel10bp_slop50.bed.gz) = 7d5468e9a6c7fd7b73d011f3c7b7c1a7
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs/second_batch_from_JZ//HG002_GRCh37_1_22_v4.1_draft_benchmark_comphetsnp10bp_slop50.bed.gz) = 10969398f759814b249ce580eec82384
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs/second_batch_from_JZ//HG002_GRCh37_1_22_v4.1_draft_benchmark_complexindel10bp_slop50.bed.gz) = c552ad07579b84fb4ea06563ed02e886
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs/second_batch_from_JZ//HG002_GRCh37_1_22_v4.1_draft_benchmark_othercomplexwithin10bp_slop50.bed.gz) = 264c673c9106ef11c76b8d098f43248f
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs/second_batch_from_JZ//HG002_GRCh37_1_22_v4.1_draft_benchmark_snpswithin10bp_slop50.bed.gz) = 18235780d6d47b59f6fb180ed9a24156
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs/second_batch_from_JZ//HG002_genomespecific_CNVsandSVs_v4.1.bed.gz) = 91b9ef16346f7ca7a63b6ad38f5cba57
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs/second_batch_from_JZ//HG002_genomespecific_complexandSVs_v3.3.2.bed.gz) = a387cbe13c35c9f139a30d8f58467db0
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs/second_batch_from_JZ//HG002_genomespecific_complexandSVs_v4.1.bed.gz) = 1e6974420442a7f1fea50f07f0141cea
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs/second_batch_from_JZ//HG003_genomespecific_complexandSVs_v3.3.2.bed.gz) = 5f55c7fb7cba5693d95f8df5e6dd29c5
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs/second_batch_from_JZ//HG004_genomespecific_complexandSVs_v3.3.2.bed.gz) = cf4c588caee1903cb73dcdf2a851873b
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs/second_batch_from_JZ//HG005_genomespecific_complexandSVs_v3.3.2.bed.gz) = eb9aef6d5f149f5b5abd42e0a884f53f
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs/second_batch_from_JZ//HG2_SKor_TrioONTCanu_intersect_HG2_SKor_TrioONTFlye_intersect_HG2_SKor_CCS15_gt10kb_GRCh37.bed.gz) = 69c08ad1b1536d26f1f0424e1c593e75
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs/second_batch_from_JZ//L1Hs_gt500.bed.gz) = e90c1a556696491bb049f5e50c4d8fec
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs/second_batch_from_JZ//MHC_GRCh37.bed.gz) = e01f1ece88408c5d1450e7fa39871f37
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs/second_batch_from_JZ//SP_SPonly_primary_assm_alignments_sorted_merged.bed.gz) = 5667857e44727e0cf6498874acc378f3
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs/second_batch_from_JZ//example_of_no_ref_regions_input_file_b37_bedtools_slop_15kb_merged.bed.gz) = 5584073339f944afc90abee3adf573db
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs/second_batch_from_JZ//expanded_150_HG002_SVs_Tier1plusTier2_v0.6.1.bed.gz) = 9e70798b2e2a770fa45fe260e8d5a86e
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs/second_batch_from_JZ//hg19.contigs.1-22.lt_500kb.bed.gz) = 77eab7c95011b2ae1e868438d7594d1a
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs/second_batch_from_JZ//hg19.vdj.bed.gz) = b1a5645226aaf78dac0b6dbd898b8ccc
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs/second_batch_from_JZ//hs37d5_hg38_minimap2_asm20_N10_gt1contig_gt1kb.bed.gz) = 959ceb383d0236c243dc9e09dd3ce511
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs/second_batch_from_JZ//hs37d5_hg38_minimap2_asm20_N10_nocovgt1kb.bed.gz) = b23e8d12c593a0208e75c2532b96b61e
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs/second_batch_from_JZ//hsd37d5.112719.inversions_slop150_chr1_22.bed.gz) = a6e290904e4f604e2857155595c81021
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs/second_batch_from_JZ//mrcanavar_intersect_ccs_1000_window_size_cnv_threshold_intersect_ont_1000_window_size_cnv_threshold.bed.gz) = dc6820d08ddc72bc74ae7f06d2069bf9
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs/second_batch_from_JZ//segdups_chr1_22_gte_10kb_identity_gte_990_segdups_counts_gt_5.bed.gz) = 532597dcc3d9533d73c360b0a9b732f7
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs/second_batch_from_JZ//union_HG002_CCS_15kb_20kb_merged_ONT_1000_window_size_combined_elliptical_outlier_threshold.bed.gz) = c003dfe1995196707ea14b63461f8811
# revised 021120
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs/revised_021120//HG001_genomespecific_RTG_PG_v3.3.2_SVs_alldifficultregions.bed.gz) = 0972703e987a2970c3ba9fd6a54360df
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs/revised_021120//HG002_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz) = 3278c1ee8fcac834e36214816ccb042c
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs/revised_021120//HG002_genomespecific_complexandSVs_alldifficultregions_v4.1.bed.gz) = 4d59751a9d3dcdd7bcefa4c924afbf3b
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs/revised_021120//HG003_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz) = 2b9bf6c19ac5244239e305f59da27781
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs/revised_021120//HG004_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz) = 4bc0e1a374e55d7cd0cbff2fa9bcd159
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs/revised_021120//HG005_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz) = ab7b2db04b376368b5b18b0fb1b047e6
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs/revised_021120//allOtherDifficultregions.bed.gz) = e3b90371841cd7c838e53336a76e7bd3
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs/revised_021120//alldifficultregions.bed.gz) = 87bcdf8a8d55e5d8ba4410cb3c28fc92
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs/revised_021120//alllowmapandsegdupregions.bed.gz) = 96e426227730d4cc759b60a1893db41c
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs/revised_021120//mm-2-merged.bed.gz) = 1e333f68c772e7d443ec16c5d1594b11
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs/revised_021120//notinHG001_genomespecific_RTG_PG_v3.3.2_SVs_alldifficultregions.bed.gz) = 36ab46964046e5339d93925deeaf11c4
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs/revised_021120//notinHG002_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz) = 101cd2dab8df0ce15eafe97351dbe7ca
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs/revised_021120//notinHG002_genomespecific_complexandSVs_alldifficultregions_v4.1.bed.gz) = 1e2cdd8e51fb8a1b3f4cb4be9a6004fc
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs/revised_021120//notinHG003_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz) = 5693079e90aacdde91fce05c50ba67c2
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs/revised_021120//notinHG004_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz) = f1029757cc0fe52672e592b21b11adba
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs/revised_021120//notinHG005_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz) = 4880d610e27e615f7ed62c0c678f3a4c
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs/revised_021120//notinalldifficultregions.bed.gz) = f863e601d50434f9d7064d915203ca3c
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs/revised_021120//notinalllowmapandsegdupregions.bed.gz) = ffb745c3ba74c21ff56894123d0b7bbd
# revised 022120
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs/revised_022120//GRCh37_refseq_cds_merged.bed.gz) = ddfa7ab300559ff03e444f62cff0f0d8
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs/revised_022120//lowmappabilityall.bed.gz) = df2022708d6cacd3e2c0b59daa10f766
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs/revised_022120//notin_GRCh37_refseq_cds_merged.bed.gz) = 752ab990845e7cd3a4c1d0b3a06c29c9
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh37/sorted_merged_noNs/revised_022120//notinlowmappabilityall.bed.gz) = 1af4c140e01a7aaa8985d11f5e18acf7

# %% [markdown]
# #### GRCh38 output files
# files output from the "Prepare Stratification BEDs for GitHub" script

# %%
date
echo "FIRST BATCH"
for f in ${OUTPUT38}/*.gz
do
md5 $f
done

echo "SECOND BATCH"
for f in ${OUTPUT38batch2}/*.gz
do
md5 $f
done
# Out:
# Fri Feb  7 10:48:23 EST 2020
# FIRST BATCH
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs//GRCh38_AllHomopolymers_gt6bp_imperfectgt10bp_slop5.bed.gz) = df2759867268f613c4b5d3043556b7aa
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs//GRCh38_AllTandemRepeats_201to10000bp_slop5.bed.gz) = d031dd132534d047bedf167d59d66070
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs//GRCh38_AllTandemRepeats_51to200bp_slop5.bed.gz) = e47464b9736943531ad6bc5488aaea5a
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs//GRCh38_AllTandemRepeats_gt10000bp_slop5.bed.gz) = e4b5375c628cc69731135346b57d851f
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs//GRCh38_AllTandemRepeats_gt100bp_slop5.bed.gz) = 2060e30642c311bd07767e8b49f82e82
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs//GRCh38_AllTandemRepeats_lt51bp_slop5.bed.gz) = bf1c01ed1cf577b28b55d178d1206fcf
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs//GRCh38_AllTandemRepeatsandHomopolymers_slop5.bed.gz) = d11a4315e2dc23d3f2081d64bb6f99ae
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs//GRCh38_SimpleRepeat

# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs//GRCh38_notinchainSelf_sorted_merged.bed.gz) = 0464cb9c78cd449a1a11b704662b9f56
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs//GRCh38_notinchainSelf_sorted_merged_gt10kb.bed.gz) = b335ffb609b71f6c8379e60d531590f8
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs//GRCh38_notinlowmappabilityall.bed.gz) = ee6ac347f80650d9aebe3409f4a3ee58
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs//GRCh38_refseq_cds_merged.bed.gz) = 2f05c497aafefd87cb58a45846f46f29
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs//GRCh38_remapped_BadPromoters_gb-2013-14-5-r51-s1.bed.gz) = d33186eae7cd3551379da507d24b488f
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs//GRCh38_remapped_HG001_GRCh37_GIAB_highconf_CG-IllFB-IllGATKHC-Ion-10X-SOLID_CHROM1-X_v.3.3.2_highconf_RTGandPGphasetransfer_comphetindel10bp_slop50.bed.gz) = c16f18908d78fbb6eabd0fb5bdd14b85
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs//GRCh38_remapped_HG001_GRCh37_GIAB_highconf_CG-IllFB-IllGATKHC-Ion-10X-SOLID_CHROM1-X_v.3.3.2_highconf_RTGandPGphasetransfer_comphetsnp10bp_slop50.bed.gz) = 8cdcece9e4c4eb73282cfe68bd9c728b
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs//GRCh38_remapped_HG001_GRCh37_GIAB_highconf_CG-IllFB-IllGATKHC-Ion-10X-SOLID_CHROM1-X_v.3.3.2_highconf_RTGandPGphasetransfer_complexindel10bp_slop50.bed.gz) = ab11884bb1ef6e66e28d77e1659cc16b
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs//GRCh38_remapped_HG001_GRCh37_GIAB_highconf_CG-IllFB-IllGATKHC-Ion-10X-SOLID_CHROM1-X_v.3.3.2_highconf_RTGandPGphasetransfer_snpswithin10bp_slop50.bed.gz) = 90d81c85c6f9091f066b68db2f082ef7
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs//GRCh38_remapped_HG002_GIAB_highconf_IllFB-IllGATKHC-CG-Ion-Solid_CHROM1-22_v3.2.2_highconf_geno2haplo_compoundhet_slop50.bed.gz) = 459859e707ca1fb524554fd61636e1a9
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs//GRCh38_remapped_HG002_GIAB_highconf_IllFB-IllGATKHC-CG-Ion-Solid_CHROM1-22_v3.2.2_highconf_varswithin50bp.bed.gz) = 4ba64b7f0ef98e6d2f1702524a03c5ba
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs//GRCh38_remapped_HG002_GRCh37_GIAB_highconf_CG-IllFB-IllGATKHC-Ion-10X-SOLID_CHROM1-22_v.3.3.2_highconf_triophased_comphetindel10bp_slop50.bed.gz) = 4e045628427449bc29f2fa7671f483e2
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs//GRCh38_remapped_HG002_GRCh37_GIAB_highconf_CG-IllFB-IllGATKHC-Ion-10X-SOLID_CHROM1-22_v.3.3.2_highconf_triophased_comphetsnp10bp_slop50.bed.gz) = 6b11b628f410f19685fbd2dfbcdbcf28
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs//GRCh38_remapped_HG002_GRCh37_GIAB_highconf_CG-IllFB-IllGATKHC-Ion-10X-SOLID_CHROM1-22_v.3.3.2_highconf_triophased_complexindel10bp_slop50.bed.gz) = 3f1da0d041287f5e331956fb7c74554b
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs//GRCh38_remapped_HG002_GRCh37_GIAB_highconf_CG-IllFB-IllGATKHC-Ion-10X-SOLID_CHROM1-22_v.3.3.2_highconf_triophased_snpswithin10bp_slop50.bed.gz) = 24bbb4084878675fed492b85c5283876
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs//GRCh38_remapped_HG002_HG003_HG004_allsvs_merged.bed.gz) = a5dc28d607db1faf7bccf759790ff865
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs//GRCh38_remapped_HG002_SVs_Tier1plusTier2_v0.6.1.bed.gz) = 79da3d04f53f825335c8d8a9717ef8cd
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs//GRCh38_remapped_HG003_GRCh37_GIAB_highconf_CG-IllFB-IllGATKHC-Ion-10X_CHROM1-22_v.3.3.2_highconf_comphetindel10bp_slop50.bed.gz) = 385c03ce262d921542a7c6ebc470bdef
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs//GRCh38_remapped_HG003_GRCh37_GIAB_highconf_CG-IllFB-IllGATKHC-Ion-10X_CHROM1-22_v.3.3.2_highconf_comphetsnp10bp_slop50.bed.gz) = 7abfca80641728de024710a87fd064da
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs//GRCh38_remapped_HG003_GRCh37_GIAB_highconf_CG-IllFB-IllGATKHC-Ion-10X_CHROM1-22_v.3.3.2_highconf_complexindel10bp_slop50.bed.gz) = b4ef4038c0c638641f7b3bafe8dea719
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs//GRCh38_remapped_HG003_GRCh37_GIAB_highconf_CG-IllFB-IllGATKHC-Ion-10X_CHROM1-22_v.3.3.2_highconf_snpswithin10bp_slop50.bed.gz) = d2177095e83f1593e0f466e49b5ed9b9
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs//GRCh38_remapped_HG004_GRCh37_GIAB_highconf_CG-IllFB-IllGATKHC-Ion-10X_CHROM1-22_v.3.3.2_highconf_comphetindel10bp_slop50.bed.gz) = 1fa36cd3f40082791cc8942a14ae58e2
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs//GRCh38_remapped_HG004_GRCh37_GIAB_highconf_CG-IllFB-IllGATKHC-Ion-10X_CHROM1-22_v.3.3.2_highconf_comphetsnp10bp_slop50.bed.gz) = 6dd3290b1035a7a88589de5efa561df8
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs//GRCh38_remapped_HG004_GRCh37_GIAB_highconf_CG-IllFB-IllGATKHC-Ion-10X_CHROM1-22_v.3.3.2_highconf_complexindel10bp_slop50.bed.gz) = 3bbc40cfbf8a25b3ab8561ae5c0a5560
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs//GRCh38_remapped_HG004_GRCh37_GIAB_highconf_CG-IllFB-IllGATKHC-Ion-10X_CHROM1-22_v.3.3.2_highconf_snpswithin10bp_slop50.bed.gz) = bc47cf0590f8057584c3f147e252beb6
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs//GRCh38_remapped_HG005_GRCh37_highconf_CG-IllFB-IllGATKHC-Ion-SOLID_CHROM1-22_v.3.3.2_highconf_comphetindel10bp_slop50.bed.gz) = e0c61c54aaad9d0bba9de7f22590ab81
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs//GRCh38_remapped_HG005_GRCh37_highconf_CG-IllFB-IllGATKHC-Ion-SOLID_CHROM1-22_v.3.3.2_highconf_comphetsnp10bp_slop50.bed.gz) = 6b3fa38a7dde32b25d028be89948f662
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs//GRCh38_remapped_HG005_GRCh37_highconf_CG-IllFB-IllGATKHC-Ion-SOLID_CHROM1-22_v.3.3.2_highconf_complexindel10bp_slop50.bed.gz) = 427fdead26d66546fb7098a3da36d7bc
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs//GRCh38_remapped_HG005_GRCh37_highconf_CG-IllFB-IllGATKHC-Ion-SOLID_CHROM1-22_v.3.3.2_highconf_snpswithin10bp_slop50.bed.gz) = d7942249cda09025dc92089cff9bb8ca
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs//GRCh38_remapped_HG005_HG006_HG007_FB_GATKHC_CG_MetaSV_allsvs_merged.bed.gz) = bf5fd59342d61d82b4925c0c2d658cc9
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs//GRCh38_remapped_NA12878_GIAB_highconf_IllFB-IllGATKHC-CG-Ion-Solid_ALLCHROM_v3.2.2_highconf_geno2haplo_compoundhet_slop50.bed.gz) = 1266b743b90c45d5f552f1fa67ed8f2b
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs//GRCh38_remapped_NA12878_GIAB_highconf_IllFB-IllGATKHC-CG-Ion-Solid_ALLCHROM_v3.2.2_highconf_varswithin50bp.bed.gz) = b138e122f2002e30d33caa293bf00c94
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs//GRCh38_remapped_PG2016-1.0_NA12878_b37_comphetindel10bp_slop50.bed.gz) = 8375c88c7f52ab52ab578f88eb8e65da
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs//GRCh38_remapped_PG2016-1.0_NA12878_b37_comphetsnp10bp_slop50.bed.gz) = e4271da3f6ca1a47599a5d77c44ddadd
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs//GRCh38_remapped_PG2016-1.0_NA12878_b37_complexindel10bp_slop50.bed.gz) = 2da2275bb5704b315fbf4eb7300d8b18
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs//GRCh38_remapped_PG2016-1.0_NA12878_b37_snpswithin10bp_slop50.bed.gz) = 6c111d15db96203331021de29b5b5a83
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs//GRCh38_remapped_PacBio_MetaSV_mergedSVs.bed.gz) = b9f3a06106758c5d9dcedb7c4ff4a011
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs//GRCh38_remapped_sp_v37.7.3.NA12878_comphetindel10bp_slop50.bed.gz) = 645c736a71e1e7b6bc41534312d4fd02
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs//GRCh38_remapped_sp_v37.7.3.NA12878_comphetsnp10bp_slop50.bed.gz) = b80149960745433baf96213382e8a521
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs//GRCh38_remapped_sp_v37.7.3.NA12878_complexindel10bp_slop50.bed.gz) = f0df3c87a631978e3ba79dd8f3a88405
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs//GRCh38_remapped_sp_v37.7.3.NA12878_snpswithin10bp_slop50.bed.gz) = 12d6af895051492f80bb043e4d81172d
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs//hg38.notinsegdups_sorted_merged.bed.gz) = 09234f12750b266313efb1129fbe609b
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs//hg38.notinsegdups_sorted_merged_gt10kb.bed.gz) = 939543513e6160b9335d49dec57bddd2
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs//hg38.segdups_sorted_merged.bed.gz) = d6d985395c5f730e75e671a4d991743c
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs//hg38.segdups_sorted_merged_gt10kb.bed.gz) = 41d043fd9e1900db140533099575b668
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs//notin_GRCh38_refseq_cds_merged.bed.gz) = 2f46a534d45e2495951b26206a845835
# SECOND BATCH
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs/second_batch_from_JZ//GCA_000001405.15_GRCh38_no_alt_plus_hs38d1_analysis_set_REF_N_slop_15kb.bed.gz) = 299d130f0fb5b5652837be318626bd4d
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs/second_batch_from_JZ//GRCh38_HG002_genomespecific_CNVsandSVs_v4.1.bed.gz) = d35089d586dc57a22b0c62767090247e
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs/second_batch_from_JZ//GRCh38_allOtherDifficultregions.bed.gz) = fc45cd821bc4d861ef7bb6c7e171b181
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs/second_batch_from_JZ//GRCh38_alldifficultregions.bed.gz) = 680cfe46a84aee3d889dc8aa4f4c1852
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs/second_batch_from_JZ//GRCh38_alllowmapandsegdupregions.bed.gz) = ffce5add6b3fd42d72289210988cfd88
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs/second_batch_from_JZ//GRCh38_mrcanavar_intersect_ccs_1000_window_size_cnv_threshold_intersect_ont_1000_window_size_cnv_threshold.bed.gz) = a372648f94c65b8ff54fdec11593f9a1
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs/second_batch_from_JZ//GRCh38_notinalldifficultregions.bed.gz) = cdec33bd09b81dc67a498b84bae92412
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs/second_batch_from_JZ//GRCh38_notinalllowmapandsegdupregions.bed.gz) = 6d086aaf1a4c46f65779724309fc268a
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs/second_batch_from_JZ//GRCh38_remapped_HG001_genomespecific_complexandSVs_v3.3.2_PG_RTG.bed.gz) = a37339b8e320ff3c2ec23347b2256f8f
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs/second_batch_from_JZ//GRCh38_remapped_HG002_genomespecific_complexandSVs_v3.3.2.bed.gz) = 1c5702cc0da1f9cf3840f4e5fd9d1df8
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs/second_batch_from_JZ//GRCh38_remapped_HG003_genomespecific_complexandSVs_v3.3.2.bed.gz) = df4c95f83afbc7b8ecd4aa081f1578d5
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs/second_batch_from_JZ//GRCh38_remapped_HG004_genomespecific_complexandSVs_v3.3.2.bed.gz) = 95b2558ef16ebfe0acd13978d3225030
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs/second_batch_from_JZ//GRCh38_remapped_HG005_genomespecific_complexandSVs_v3.3.2.bed.gz) = 43419f7b78fb5859f49f0a8941adf94b
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs/second_batch_from_JZ//GRCh38_union_HG002_CCS_15kb_20kb_merged_ONT_1000_window_size_combined_elliptical_outlier_threshold.bed.gz) = 87dca1fc7781f653be62aac8dab0040c
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs/second_batch_from_JZ//HG001_genomespecific_RTG_PG_v3.3.2_SVs_alldifficultregions.bed.gz) = 631a9e25d0aa47f5560d46722cc4d7e7
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs/second_batch_from_JZ//HG002_GRCh38_1_22_v4.1_draft_benchmark_comphetindel10bp_slop50.bed.gz) = 900471a88e8c39e617a51066a4cf7135
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs/second_batch_from_JZ//HG002_GRCh38_1_22_v4.1_draft_benchmark_comphetsnp10bp_slop50.bed.gz) = f12f85f0759e64e65b1ff51cdf353ccd
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs/second_batch_from_JZ//HG002_GRCh38_1_22_v4.1_draft_benchmark_complexindel10bp_slop50.bed.gz) = a82da13ed779093ea82482a8669df47c
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs/second_batch_from_JZ//HG002_GRCh38_1_22_v4.1_draft_benchmark_othercomplexwithin10bp_slop50.bed.gz) = 51089011a9363e4e19bfae7f85458c83
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs/second_batch_from_JZ//HG002_GRCh38_1_22_v4.1_draft_benchmark_snpswithin10bp_slop50.bed.gz) = fdd64ab550393dd8dc15a4aee06c7c4c
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs/second_batch_from_JZ//HG002_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz) = b7fcd6bed50112bdf0f6351caeac398f
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs/second_batch_from_JZ//HG002_genomespecific_complexandSVs_alldifficultregions_v4.1.bed.gz) = 28c30a4d46903a8fb1629701ab2be861
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs/second_batch_from_JZ//HG002_genomespecific_complexandSVs_v4.1.bed.gz) = df1d0677d32e66c8d157988b88a18e52
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs/second_batch_from_JZ//HG003_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz) = c36edc0c385af1cfdbf99d1b1f782b0f
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs/second_batch_from_JZ//HG004_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz) = 44be89cbf38b798c046775dca13f9d50
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs/second_batch_from_JZ//HG005_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz) = 64d62653b66e09ced31bff80b8798acd
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs/second_batch_from_JZ//HG2_SKor_TrioONTCanu_intersect_HG2_SKor_TrioONTFlye_intersect_HG2_SKor_CCS15_gt10kb_GRCh38.bed.gz) = d759aa90506797d139d5b30bd3b256e2
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs/second_batch_from_JZ//MHC_GRCh38.bed.gz) = 094abf0f05efc34715492ce182398a7b
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs/second_batch_from_JZ//SVMergeInversions.GRCh38.120519.clustered_slop150_chr1_22.bed.gz) = ca46f70811964048c2da20244f98a86e
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs/second_batch_from_JZ//expanded_150_GRCh38_remapped_HG002_SVs_Tier1plusTier2_v0.6.1.bed.gz) = b7e469f799d8cbbc3e16659c6f93f047
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs/second_batch_from_JZ//hg38.contigs.1-22.lt_500kb.bed.gz) = b9e177b53648c7e9135cb797a7fb57db
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs/second_batch_from_JZ//hg38.rmsk.L1H_gt500.bed.gz) = 8acce134f9188e131c12fa1252a24b60
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs/second_batch_from_JZ//hg38.segdups_chr1-22_gte_10kb_identity_gte_990_segdups_counts_gt_5.bed.gz) = fe9c239d54f25088fd60e265cc9a7e66
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs/second_batch_from_JZ//hg38.vdj.bed.gz) = bd02a16547c5982f794d45d2262d603b
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs/second_batch_from_JZ//notinHG001_genomespecific_RTG_PG_v3.3.2_SVs_alldifficultregions.bed.gz) = 3d6900033962a174b858674fe1722eae
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs/second_batch_from_JZ//notinHG002_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz) = af5633ec975d414fe4c0aecb0eac403a
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs/second_batch_from_JZ//notinHG002_genomespecific_complexandSVs_alldifficultregions_v4.1.bed.gz) = 0541b398290dcbc438fc737954a5ffc7
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs/second_batch_from_JZ//notinHG003_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz) = e2c4c766ea5449ac74a89cea0dabf202
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs/second_batch_from_JZ//notinHG004_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz) = bb83e9ef4284bd0dea012ecb4a418645
# MD5 (/Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh38/sorted_merged_noNs/second_batch_from_JZ//notinHG005_genomespecific_complexandSVs_alldifficultregions_v3.3.2.bed.gz) = c84fa0dd1a874bd2fe1ae306469793d5

# %% [markdown]
# ## OUTPUT FILE LOCATIONS
# #### files for validation plots
# /Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh3X/sorted_merged_noNs/
#
# /Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh3X/sorted_merged_noNs/second_batch_from_JZ/
#
# /Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh3X/sorted_merged_noNs/second_batch_from_JZ/revised_021120
#
# *files that have undergone a revision have been deleted in their original output directory.
#
# #### files for release
# All stratification files for release were subsequently renamed with Stratification_BEDfile_rename.R script and put in /Users/jmcdani/Documents/GiaB/Benchmarking/GRCh38_stratification_validation/data/stratifications/GRCh3X/ALL_GRCh3X_sorted_merged_renamed_BEDs_for_GitHub/
